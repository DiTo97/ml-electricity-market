# %% [markdown]
# # Problem
#
# ### 1. Loading data
# Loading the generated CSV files for training and test set.<br>
# Refer to the file <i>code/preprocessing/Time-series analysis.ipynb</i> to see how they are generated.

# %%
import pandas as pd

print('Loading data...')

# Load CSVs as Pandas DFs
training_df = pd.read_csv('./preprocessing/generated_csv/IREN_train.csv',  index_col='date', header=0, sep=';')

test_X_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_X.csv', index_col='date', header=0, sep=';')
test_Y_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_Y.csv', index_col='date', header=0, sep=';')

print('Data loaded successfully\n')

print('Training set: {:d} x {:d}'.format(training_df.shape[0],training_df.shape[1]))
print('Test set: {:d} x {:d}'.format(test_X_df.shape[0],test_X_df.shape[1]))
# Out:
# Loading data...
# Data loaded successfully
#
# Training set: 11480 x 26
# Test set: 196 x 25

# %% [markdown]
# Inspect the training set

# %%
pd.set_option('display.max_columns', 500)
training_df.head()
# Out:
#                 participant technology  n_acc_offers  temp_adjusted_mean  \
# date
# 2018-01-01  participant_116       ccgt             0            6.705066
# 2018-01-02  participant_116       ccgt             0            7.323310
# 2018-01-03  participant_116       ccgt             0            5.457443
# 2018-01-04  participant_116       ccgt             0            6.347944
# 2018-01-05  participant_116       ccgt             0            7.350037
#
#             renewable_nrg_tot  hydro_tot  ccgt_prod_cost_mean  \
# date
# 2018-01-01         193.621283  58.437416                 49.3
# 2018-01-02         227.393858  82.925698                 49.2
# 2018-01-03         226.303612  88.067452                 48.2
# 2018-01-04         205.518491  80.093910                 47.5
# 2018-01-05         192.497161  89.390917                 47.2
#
#             accepted_mgp_nrg_tot  thermal_nrg_tot  accepted_price_mgp_mean  \
# date
# 2018-01-01            215.816814       285.971637                45.337500
# 2018-01-02            270.208227       373.068869                39.955061
# 2018-01-03            278.715408       393.063962                52.245000
# 2018-01-04            268.675256       391.537633                42.843750
# 2018-01-05            285.251325       441.394672                51.375833
#
#             n_acc_offers_3  n_acc_offers_7  temp_adjusted_mean_3  \
# date
# 2018-01-01             0.0             0.0              6.495273
# 2018-01-02             0.0             0.0              6.495273
# 2018-01-03             0.0             0.0              6.376232
# 2018-01-04             0.0             0.0              6.385141
# 2018-01-05             0.0             0.0              7.462011
#
#             temp_adjusted_mean_7  renewable_nrg_tot_3  renewable_nrg_tot_7  \
# date
# 2018-01-01              7.367634           215.772918           190.158962
# 2018-01-02              7.367634           215.772918           190.158962
# 2018-01-03              7.367634           219.738654           190.158962
# 2018-01-04              7.367634           208.106421           190.158962
# 2018-01-05              7.977326           180.812083           190.468964
#
#             hydro_tot_3  hydro_tot_7  ccgt_prod_cost_mean_3  \
# date
# 2018-01-01    76.476855    75.947558              48.900000
# 2018-01-02    76.476855    75.947558              48.900000
# 2018-01-03    83.695687    75.947558              48.300000
# 2018-01-04    85.850760    75.947558              47.633333
# 2018-01-05    79.551112    81.037431              47.100000
#
#             ccgt_prod_cost_mean_7  accepted_mgp_nrg_tot_3  \
# date
# 2018-01-01                   47.8              254.913483
# 2018-01-02                   47.8              254.913483
# 2018-01-03                   47.8              272.532964
# 2018-01-04                   47.8              277.547330
# 2018-01-05                   47.7              264.127602
#
#             accepted_mgp_nrg_tot_7  thermal_nrg_tot_3  thermal_nrg_tot_7  \
# date
# 2018-01-01              254.816386         350.701489         376.099673
# 2018-01-02              254.816386         350.701489         376.099673
# 2018-01-03              254.816386         385.890155         376.099673
# 2018-01-04              254.816386         408.665422         376.099673
# 2018-01-05              268.326490         406.138143         405.812126
#
#             accepted_price_mgp_mean_3  accepted_price_mgp_mean_7
# date
# 2018-01-01                  45.845854                  46.321378
# 2018-01-02                  45.845854                  46.321378
# 2018-01-03                  45.014604                  46.321378
# 2018-01-04                  48.821528                  46.321378
# 2018-01-05                  47.205694                  46.358759

# %% [markdown]
# <mark> **Remark** </mark>
#
# Each couple (`participant`,`technology`) identifies a different time series, with `n_acc_offers` being the target variable.
# Values of the time series are provided daily, hence it is said that the lag of the time series is 1 day.
#
# All the columns to the right of `temp_adjusted_mean` (included) are the so called lag features and they have equal values for each time series. The columns `n_acc_offers_3` and `n_acc_offers_7` make an exception since they refer to the mean of the target variable from the previous week, for each time series computed with a rolling window of 3 and 7 days, respectively.
#
# The following table shows exactly the output we want to predict for each time series of the given 28 pairs (`participant`,`technology`) in the assigned week *22-28 February 2019.*

# %%
target_example_df = pd.read_pickle('./preprocessing/shared_data/target/target_number_of_plants.pkl')
target_example_df.tail(7)
# Out:
#             number_of_plant                                                 \
# participant participant_116                                participant_120
# technology             ccgt ccgt400 ccgt800 pump reservoir         ccgt800
# date
# 20190222                  0       1       1    1         2               1
# 20190223                  0       1       0    1         2               1
# 20190224                  0       1       0    1         2               1
# 20190225                  0       2       0    1         2               1
# 20190226                  0       2       0    1         2               1
# 20190227                  0       2       1    1         2               1
# 20190228                  0       2       1    1         2               1
#
#                                                                ...  \
# participant participant_146           participant_158          ...
# technology             pump reservoir         ccgt400 ccgt800  ...
# date                                                           ...
# 20190222                  1         0               3       1  ...
# 20190223                  1         0               3       1  ...
# 20190224                  1         0               3       1  ...
# 20190225                  2         0               3       1  ...
# 20190226                  1         0               3       1  ...
# 20190227                  1         0               3       0  ...
# 20190228                  2         0               3       1  ...
#
#                                                                   \
# participant participant_87 participant_89
# technology         ccgt400        ccgt400 ccgt800 coal reservoir
# date
# 20190222                 5              0       2    2         3
# 20190223                 6              0       0    2         3
# 20190224                 6              0       0    2         3
# 20190225                 5              0       2    2         3
# 20190226                 5              1       2    2         3
# 20190227                 5              1       2    2         3
# 20190228                 5              0       2    2         3
#
#
# participant participant_96
# technology         ccgt400 ccgt800 coal pump reservoir
# date
# 20190222                 2       0    3    0         1
# 20190223                 1       0    3    0         2
# 20190224                 2       0    3    0         1
# 20190225                 2       0    3    1         2
# 20190226                 2       0    3    2         2
# 20190227                 2       0    3    3         3
# 20190228                 2       0    4    1         3
#
# [7 rows x 28 columns]

# %% [markdown]
# The given pairs (`participant`,`technology`) are:

# %%
unique_pairs = training_df.groupby(['participant','technology']) \
    .size().reset_index().drop(columns={0}).values

print('Here are the given {} pairs\n'.format(len(unique_pairs)))
print(unique_pairs)
# Out:
# Here are the given 28 pairs
#
# [['participant_116' 'ccgt']
#  ['participant_116' 'ccgt400']
#  ['participant_116' 'ccgt800']
#  ['participant_116' 'pump']
#  ['participant_116' 'reservoir']
#  ['participant_120' 'ccgt800']
#  ['participant_146' 'pump']
#  ['participant_146' 'reservoir']
#  ['participant_158' 'ccgt400']
#  ['participant_158' 'ccgt800']
#  ['participant_158' 'pump']
#  ['participant_158' 'reservoir']
#  ['participant_176' 'ccgt800']
#  ['participant_21' 'reservoir']
#  ['participant_60' 'ccgt400']
#  ['participant_75' 'ccgt400']
#  ['participant_75' 'ccgt800']
#  ['participant_87' 'ccgt']
#  ['participant_87' 'ccgt400']
#  ['participant_89' 'ccgt400']
#  ['participant_89' 'ccgt800']
#  ['participant_89' 'coal']
#  ['participant_89' 'reservoir']
#  ['participant_96' 'ccgt400']
#  ['participant_96' 'ccgt800']
#  ['participant_96' 'coal']
#  ['participant_96' 'pump']
#  ['participant_96' 'reservoir']]

# %% [markdown]
# ### 2. Using Machine Learning custom models
#
# The problem is approached with a "*Divide and Conquer*" strategy: a regression model is trained for each given participant of the market instead of predicting each individual time series. Here we show the list of participants.

# %%
# Unique participants
u_participants = training_df.participant.unique()

print("Total regression model to be trained: {}".format(len(u_participants)))
print(u_participants)
# Out:
# Total regression model to be trained: 11
# ['participant_116' 'participant_120' 'participant_146' 'participant_158'
#  'participant_176' 'participant_21' 'participant_60' 'participant_75'
#  'participant_87' 'participant_89' 'participant_96']

# %% [markdown]
# As a consequence, the column `technology` is the only feature to be encoded into int.

# %%
from sklearn.preprocessing import LabelEncoder

# Unique technologies
u_technologies = training_df.technology.unique()

# Create an automatic encoding
le = LabelEncoder()

# N.B. LabelEncorder.fit() is a singleton!
enc_technologies = le.fit(u_technologies)

# Create a dictionary to show the mapping executed
le_mapping_technologies = dict(zip(enc_technologies.classes_,
        enc_technologies.transform(le.classes_)))

# Encode training and test set
training_df.technology = enc_technologies.transform(training_df.technology)

test_X_df.technology = enc_technologies.transform(test_X_df.technology)
test_Y_df.technology = enc_technologies.transform(test_Y_df.technology)

print('The encoding is the following:')

le_mapping_technologies
# Out:
# The encoding is the following:
# {'ccgt': 0, 'ccgt400': 1, 'ccgt800': 2, 'coal': 3, 'pump': 4, 'reservoir': 5}

# %% [markdown]
# According to the "Divide and conquer" strategy, each regression model corresponding to a participant is cross-validated using the 5-Fold Cross Validation strategy. At the end, each participant will have a list of 5 its own regression models tuned with the best parameters. The output for each time series (`participant`,`technology`) is predicted as the mean of the 5 regression models corresponding to the participant.
#
# Both of the algorithms implemented share a common helper class to keep track of the best models (and their metadata) during 5-Fold Cross Validation, presented here. In the next sections each algorithm is presented and tuned separately with different functions. Final results and comparisons with the solution obtained during the C1A0 Hackathon are provided and furtherly commentend in the section 5-6 of the report.

# %%
class CVInfo():
    """
    Helper class to keep track of the best models
    and metadata after 5-Fold CV via a
    Divide and conquer strategy
    
    Attributes
    ------------
    score: float
    RMSE obtained by 5 regression models
    
    models: list
    List of 5 regression model (class GBDT or
    RandomForestRegressor) trained during a 
    5-Fold Cross validation
    
    params: dict
    Set of parameters used in the models to
    obtain the score
    
    """
    
    def __init__(self): 
        self.score  = None
        self.models = []
        self.params = {}
        
    def check_score(self, score, models=[], params={}):
        """
        Update the attributes according to the score

        Parameters
        ------------
        score: float
        Score to compare with the models included
        in this object

        models: list
        List of 5 regression model (class GBDT or
        RandomForestRegressor) trained during a 
        5-Fold Cross validation

        params: dict
        Set of parameters used in the models to
        obtain the score

        """
        if self.score is None or score > self.score:
            self.score  = score
            self.models = models
            self.params = params
            
            return True
        else:
            return False

# %% [markdown]
# #### Random Forest (by Gianvito Losapio)
#
# The implementation of Random Forest is included in the folder <i>randforest/src</i>:
#
# - <i>decision_tree.py</i> contains the classes:
#     - `Tree` which models a regression tree
#     - `Node` which models a single node of the tree and contains the function `build` used to grow the regression tree according to the greedy solution described in the section 3 of the report
#
#
# - <i>rf.py</i> contains the class `RandomForestRegressor` used to create the random forest model
#
#
# - <i>utils.py</i> contains the function used to compute the Mean Square Error (MSE) whenever needed.

# %%
import numpy as np
import pandas as pd
import sys

# Generate random fold indexes
from sklearn.model_selection import KFold

# Custom imports
from randforest.src.rf import RandomForestRegressor
from randforest.src.utils import calculate_MSE

# %% [markdown]
# For the sake of simplicity the 5-Fold Cross Validation is executed with only 6 different combination of parameters:
# - `n_estimators`: the number of the trees in the forest
# - `max_depth`: the maximum depth of the single trees
# - `max_features`: the number of random features to consider when looking for the best split
#
# The elapsed time is: 1h:21m:44s (Intel Core i7-8750H @ 2.20 GHz, 8 GB RAM)

# %%
# Comment the following lines if you want to execute CV again
import pickle

with open('best_CV_info_RF.pickle','rb') as f:
     best_CV_info = pickle.load(f)

# %%
from sklearn.model_selection import KFold

def launch_IREN_VFoldCV(training_df, params_combinats,
                            participants, seed=None, num_folds=5,
                            out_features=['n_acc_offers', 'participant']):
    """
    Function to execute V-Fold CV tuned for IREN case study
    
    Parameters
    ------------
    training_df: Pandas dataframe
    Training set
    
    params_combinats: list of dictionaries
    List of parameters combinations to be cross-validated
    
    participants: list
    List of participants given by IREN
    
    seed: int [default=None]
    If None non-repeatable fold split is executed
    
    num_folds: int [default=5]
    Number of folds for V-Fold CV
    
    out_features: list
    Columns to be dropped in the validation fold
    for the prediction
    
    """
    
    from datetime import datetime
    CV_start_time = datetime.now()
    
    # Output CV info per participant. At the end of VFoldCV
    # best_CV_info[participant] will contain a CV info object
    # for each participant saving the model, the set of best parameters,
    # the score
    best_CV_info = {}

    # Init CV_info dict
    for participant in participants:
        best_CV_info[participant] = CVInfo()
        
    for params in params_combinats:
        print('Testing CV with params:', params)
        current_RF_models = {}

        for participant in participants:
            print("{}-Fold CV for participant:".format(num_folds), participant)

            KF_generator = KFold(n_splits=num_folds, random_state=seed)
            current_RF_models[participant] = []

            # Divide and conquer strategy: train a model for a single participant
            # Separate current XY sets
            X_train_Participant = training_df.loc[training_df.participant
                                        == participant].reset_index(drop=True)

            Y_train_Participant = X_train_Participant.n_acc_offers

            # Drop useless columns
            X_train_Participant.drop(columns=out_features, inplace=True)

            CV_score = 0

            # Fit the CART learners on the current fold
            for fold_idx, (train_idx, valid_idx) in enumerate(
                                KF_generator.split(X_train_Participant, Y_train_Participant)):

                X_train, X_valid = X_train_Participant.loc[train_idx].to_numpy(), \
                        X_train_Participant.loc[valid_idx].to_numpy()

                Y_train, Y_valid = Y_train_Participant.iloc[train_idx].to_numpy(), \
                        Y_train_Participant.iloc[valid_idx].to_numpy()

                
                # Create a RF model
                model_RF = RandomForestRegressor()

                # Train
                model_RF.train(X_train, Y_train, X_valid, Y_valid, params)

                current_RF_models[participant].append(model_RF)
                    
                Y_pred_valid = model_RF.predict(X_valid)

                valid_RMSE = np.sqrt(calculate_MSE(Y_valid, Y_pred_valid))
                
                print("Participant: {}, at fold_idx {} with RMSE: {}\n" \
                             .format(participant, fold_idx, valid_RMSE))

                CV_score += valid_RMSE / num_folds

            # Update the best
            if best_CV_info[participant].check_score(CV_score,
                        current_RF_models[participant], params):
                print('Participant: {}, got a new best CV score: {} with params: {}\n' \
                                  .format(participant, CV_score, params))
    
    print('CV finished. Elapsed time: {}' \
                .format(datetime.now() - CV_start_time))
            
    return best_CV_info

# %%
# Set of parameters chosen for 5-Fold Cross Validation

# Max features as square root of the number of features
num_features = training_df.shape[1] - 2
max_features = int(np.sqrt(num_features))

# Custom building options
params = [
    {
    'n_estimators': 10,
    'max_depth': 3,
    },
    {
    'n_estimators': 10,
    'max_depth': 5,       
    },
    {
    'n_estimators': 5,
    'max_depth': 7,
    'max_features': max_features               
    },
    {
    'n_estimators': 5,
    'max_depth': 7,      
    },
    {
    'n_estimators': 5,
    'max_depth': 10,
    'max_features': max_features        
        
    },
    {
    'n_estimators': 5,
    'max_depth': 13,
    'max_features': max_features       
        
    }
]
# Out:
# Testing CV with params: {'n_estimators': 10, 'max_depth': 3}
# 5-Fold CV for participant: participant_116
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.0743902439, Validation L2 error: 2.0024390244, Elapsed time: 0:00:04.486805
# Tree number   2, Training L2 error: 0.0713414634, Validation L2 error: 2.3390243902, Elapsed time: 0:00:04.489759
# Tree number   3, Training L2 error: 0.0603658537, Validation L2 error: 2.3000000000, Elapsed time: 0:00:04.512898
# Tree number   4, Training L2 error: 0.0774390244, Validation L2 error: 2.5902439024, Elapsed time: 0:00:04.402202
# Tree number   5, Training L2 error: 0.0768292683, Validation L2 error: 2.0609756098, Elapsed time: 0:00:04.329844
# Tree number   6, Training L2 error: 0.0774390244, Validation L2 error: 3.4048780488, Elapsed time: 0:00:04.805047
# Tree number   7, Training L2 error: 0.0756097561, Validation L2 error: 2.2512195122, Elapsed time: 0:00:04.702824
# Tree number   8, Training L2 error: 0.0780487805, Validation L2 error: 1.8487804878, Elapsed time: 0:00:04.285739
# Tree number   9, Training L2 error: 0.0682926829, Validation L2 error: 3.0536585366, Elapsed time: 0:00:04.600354
# Tree number  10, Training L2 error: 0.2080792683, Validation L2 error: 0.6707317073, Elapsed time: 0:00:03.617412
# Training finished. Elapsed time: 0:00:35.595474
#
# Participant: participant_158, at fold_idx 0 with RMSE: 0.8184235292137755
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.2576219512, Validation L2 error: 0.6707317073, Elapsed time: 0:00:03.316767
# Tree number   2, Training L2 error: 0.2500000000, Validation L2 error: 0.3170731707, Elapsed time: 0:00:03.361883
# Tree number   3, Training L2 error: 0.2842987805, Validation L2 error: 0.4115853659, Elapsed time: 0:00:03.345304
# Tree number   4, Training L2 error: 0.2538109756, Validation L2 error: 0.6707317073, Elapsed time: 0:00:03.482360
# Tree number   5, Training L2 error: 0.2416158537, Validation L2 error: 0.1463414634, Elapsed time: 0:00:03.421421
# Tree number   6, Training L2 error: 0.2431402439, Validation L2 error: 0.4573170732, Elapsed time: 0:00:03.437751
# Tree number   7, Training L2 error: 0.2721036585, Validation L2 error: 0.5853658537, Elapsed time: 0:00:03.449822
# Tree number   8, Training L2 error: 0.2362804878, Validation L2 error: 0.3414634146, Elapsed time: 0:00:03.458248
# Tree number   9, Training L2 error: 0.2400914634, Validation L2 error: 1.1615853659, Elapsed time: 0:00:03.453445
# Tree number  10, Training L2 error: 0.2248475610, Validation L2 error: 0.4146341463, Elapsed time: 0:00:03.447641
# Training finished. Elapsed time: 0:00:34.174642
#
# Participant: participant_158, at fold_idx 1 with RMSE: 0.5369289365705944
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.1920731707, Validation L2 error: 0.2987804878, Elapsed time: 0:00:03.454647
# Tree number   2, Training L2 error: 0.2042682927, Validation L2 error: 0.3048780488, Elapsed time: 0:00:03.462177
# Tree number   3, Training L2 error: 0.2141768293, Validation L2 error: 0.3048780488, Elapsed time: 0:00:03.552979
# Tree number   4, Training L2 error: 0.1882621951, Validation L2 error: 0.3323170732, Elapsed time: 0:00:03.516856
# Tree number   5, Training L2 error: 0.2301829268, Validation L2 error: 0.5731707317, Elapsed time: 0:00:03.491813
# Tree number   6, Training L2 error: 0.2271341463, Validation L2 error: 0.5640243902, Elapsed time: 0:00:03.538916
# Tree number   7, Training L2 error: 0.2339939024, Validation L2 error: 0.3597560976, Elapsed time: 0:00:03.454750
# Tree number   8, Training L2 error: 0.2096036585, Validation L2 error: 0.3048780488, Elapsed time: 0:00:03.501185
# Tree number   9, Training L2 error: 0.2278963415, Validation L2 error: 0.3079268293, Elapsed time: 0:00:03.452107
# Tree number  10, Training L2 error: 0.2080792683, Validation L2 error: 0.3048780488, Elapsed time: 0:00:03.438623
# Training finished. Elapsed time: 0:00:34.865018
#
# Participant: participant_158, at fold_idx 2 with RMSE: 0.47353754326140685
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.1760670732, Validation L2 error: 0.5335365854, Elapsed time: 0:00:03.631447
# Tree number   2, Training L2 error: 0.1692073171, Validation L2 error: 0.5640243902, Elapsed time: 0:00:03.596595
# Tree number   3, Training L2 error: 0.1638719512, Validation L2 error: 0.6463414634, Elapsed time: 0:00:03.692074
# Tree number   4, Training L2 error: 0.1745426829, Validation L2 error: 0.6158536585, Elapsed time: 0:00:03.608127
# Tree number   5, Training L2 error: 0.1653963415, Validation L2 error: 0.6280487805, Elapsed time: 0:00:03.627547
# Tree number   6, Training L2 error: 0.1783536585, Validation L2 error: 0.5731707317, Elapsed time: 0:00:03.574908
# Tree number   7, Training L2 error: 0.1547256098, Validation L2 error: 0.5243902439, Elapsed time: 0:00:03.542696
# Tree number   8, Training L2 error: 0.1676829268, Validation L2 error: 0.5091463415, Elapsed time: 0:00:03.647938
# Tree number   9, Training L2 error: 0.1791158537, Validation L2 error: 0.6189024390, Elapsed time: 0:00:03.573978
# Tree number  10, Training L2 error: 0.1692073171, Validation L2 error: 0.6280487805, Elapsed time: 0:00:03.563908
# Training finished. Elapsed time: 0:00:36.074842
#
# Participant: participant_158, at fold_idx 3 with RMSE: 0.6620367685611043
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.2423780488, Validation L2 error: 0.3079268293, Elapsed time: 0:00:03.532330
# Tree number   2, Training L2 error: 0.1966463415, Validation L2 error: 0.4725609756, Elapsed time: 0:00:03.563075
# Tree number   3, Training L2 error: 0.2050304878, Validation L2 error: 0.4146341463, Elapsed time: 0:00:03.630945
# Tree number   4, Training L2 error: 0.2065548780, Validation L2 error: 0.4237804878, Elapsed time: 0:00:03.555591
# Tree number   5, Training L2 error: 0.2385670732, Validation L2 error: 0.3658536585, Elapsed time: 0:00:03.672769
# Tree number   6, Training L2 error: 0.2461890244, Validation L2 error: 0.3018292683, Elapsed time: 0:00:03.501822
# Tree number   7, Training L2 error: 0.2492378049, Validation L2 error: 0.4695121951, Elapsed time: 0:00:03.606417
# Tree number   8, Training L2 error: 0.2423780488, Validation L2 error: 0.3567073171, Elapsed time: 0:00:03.558544
# Tree number   9, Training L2 error: 0.2759146341, Validation L2 error: 0.4664634146, Elapsed time: 0:00:03.625809
# Tree number  10, Training L2 error: 0.2096036585, Validation L2 error: 0.5914634146, Elapsed time: 0:00:03.617515
# Training finished. Elapsed time: 0:00:35.880385
#
# Participant: participant_158, at fold_idx 4 with RMSE: 0.5412271512667234
#
# Participant: participant_158, got a new best CV score: 0.6064307857747209 with params: {'n_estimators': 10, 'max_depth': 3}
#
# 5-Fold CV for participant: participant_176
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Tree number   9, Training L2 error: 0.0060975610, Validation L2 error: 0.3658536585, Elapsed time: 0:00:00.916472
# Tree number  10, Training L2 error: 0.0060975610, Validation L2 error: 0.3048780488, Elapsed time: 0:00:00.948227
# Training finished. Elapsed time: 0:00:09.120951
#
# Participant: participant_21, at fold_idx 3 with RMSE: 0.5361334016737289
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.0548780488, Validation L2 error: 0.0731707317, Elapsed time: 0:00:00.916155
# Tree number   2, Training L2 error: 0.0304878049, Validation L2 error: 0.0975609756, Elapsed time: 0:00:00.903479
# Tree number   3, Training L2 error: 0.0304878049, Validation L2 error: 0.1097560976, Elapsed time: 0:00:00.882772
# Tree number   4, Training L2 error: 0.0274390244, Validation L2 error: 0.1219512195, Elapsed time: 0:00:00.898890
# Tree number   5, Training L2 error: 0.0518292683, Validation L2 error: 0.0487804878, Elapsed time: 0:00:00.966446
# Tree number   6, Training L2 error: 0.0609756098, Validation L2 error: 0.1341463415, Elapsed time: 0:00:01.048809
# Tree number   7, Training L2 error: 0.0579268293, Validation L2 error: 0.0975609756, Elapsed time: 0:00:01.031682
# Tree number   8, Training L2 error: 0.0182926829, Validation L2 error: 0.1585365854, Elapsed time: 0:00:00.992784
# Tree number   9, Training L2 error: 0.0670731707, Validation L2 error: 0.0609756098, Elapsed time: 0:00:00.916327
# Tree number  10, Training L2 error: 0.0274390244, Validation L2 error: 0.0975609756, Elapsed time: 0:00:00.885401
# Training finished. Elapsed time: 0:00:09.442745
#
# Participant: participant_21, at fold_idx 4 with RMSE: 0.2225133594235439
#
# Participant: participant_21, got a new best CV score: 0.34192865340760636 with params: {'n_estimators': 10, 'max_depth': 3}
#
# 5-Fold CV for participant: participant_60
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.0365853659, Validation L2 error: 0.8658536585, Elapsed time: 0:00:00.945892
# Tree number   2, Training L2 error: 0.0274390244, Validation L2 error: 0.0243902439, Elapsed time: 0:00:00.899176
# Tree number   3, Training L2 error: 0.0579268293, Validation L2 error: 0.8414634146, Elapsed time: 0:00:00.946128
# Tree number   4, Training L2 error: 0.0365853659, Validation L2 error: 0.2073170732, Elapsed time: 0:00:00.927961
# Tree number   5, Training L2 error: 0.0579268293, Validation L2 error: 0.2073170732, Elapsed time: 0:00:00.937486
# Tree number   6, Training L2 error: 0.0731707317, Validation L2 error: 0.8658536585, Elapsed time: 0:00:00.961005
# Tree number   7, Training L2 error: 0.0609756098, Validation L2 error: 0.6707317073, Elapsed time: 0:00:00.942973
# Tree number   8, Training L2 error: 0.0365853659, Validation L2 error: 0.7560975610, Elapsed time: 0:00:00.917890
# Tree number   9, Training L2 error: 0.0304878049, Validation L2 error: 0.0731707317, Elapsed time: 0:00:00.909759
# Tree number  10, Training L2 error: 0.0304878049, Validation L2 error: 0.2073170732, Elapsed time: 0:00:00.928041
# Training finished. Elapsed time: 0:00:09.316311
#
# Participant: participant_60, at fold_idx 0 with RMSE: 0.5001219363510385
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.0000000000, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.945749
# Tree number   2, Training L2 error: 0.0030487805, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.867930
# Tree number   3, Training L2 error: 0.0030487805, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.914120
# Tree number   4, Training L2 error: 0.0091463415, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.914963
# Tree number   5, Training L2 error: 0.0152439024, Validation L2 error: 0.3170731707, Elapsed time: 0:00:00.984015
# Tree number   6, Training L2 error: 0.0060975610, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.945984
# Tree number   7, Training L2 error: 0.0274390244, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.969437
# Tree number   8, Training L2 error: 0.0000000000, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.958149
# Tree number   9, Training L2 error: 0.0030487805, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.946877
# Tree number  10, Training L2 error: 0.0091463415, Validation L2 error: 0.2804878049, Elapsed time: 0:00:00.930381
# Training finished. Elapsed time: 0:00:09.377605
#
# Participant: participant_60, at fold_idx 1 with RMSE: 0.5278811765779926
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'max_features': None}
# Training started...
# Tree number   1, Training L2 error: 0.0243902439, Validation L2 error: 0.4146341463, Elapsed time: 0:00:00.946658
# Tree number   2, Training L2 error: 0.0182926829, Validation L2 error: 0.1829268293, Elapsed time: 0:00:00.837123
# Tree number   3, Training L2 error: 0.0304878049, Validation L2 error: 0.2195121951, Elapsed time: 0:00:00.992219
# Tree number   4, Training L2 error: 0.0396341463, Validation L2 error: 0.3658536585, Elapsed time: 0:00:00.922586
# Tree number   5, Training L2 error: 0.0304878049, Validation L2 error: 0.1219512195, Elapsed time: 0:00:00.884083
# Tree number   6, Training L2 error: 0.0365853659, Validation L2 error: 0.1951219512, Elapsed time: 0:00:00.883943
# Tree number   7, Training L2 error: 0.0304878049, Validation L2 error: 0.1829268293, Elapsed time: 0:00:00.898366
# Tree number   8, Training L2 error: 0.0243902439, Validation L2 error: 0.2682926829, Elapsed time: 0:00:00.855926
# ...
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 1.4512195122, Elapsed time: 0:00:00.743159
# Training finished. Elapsed time: 0:00:03.779418
#
# Participant: participant_75, at fold_idx 1 with RMSE: 0.7480054780026356
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0045731707, Validation L2 error: 1.0243902439, Elapsed time: 0:00:00.751198
# Tree number   2, Training L2 error: 0.0030487805, Validation L2 error: 2.0853658537, Elapsed time: 0:00:00.787662
# Tree number   3, Training L2 error: 0.0228658537, Validation L2 error: 0.8231707317, Elapsed time: 0:00:00.823180
# Tree number   4, Training L2 error: 0.0000000000, Validation L2 error: 1.4634146341, Elapsed time: 0:00:00.831401
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 1.0975609756, Elapsed time: 0:00:00.851188
# Training finished. Elapsed time: 0:00:04.044629
#
# Participant: participant_75, at fold_idx 2 with RMSE: 0.8179391115748791
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0015243902, Validation L2 error: 0.8780487805, Elapsed time: 0:00:00.918561
# Tree number   2, Training L2 error: 0.0167682927, Validation L2 error: 3.6280487805, Elapsed time: 0:00:00.796284
# Tree number   3, Training L2 error: 0.0015243902, Validation L2 error: 1.6890243902, Elapsed time: 0:00:00.849042
# Tree number   4, Training L2 error: 0.0106707317, Validation L2 error: 3.2134146341, Elapsed time: 0:00:00.761488
# Tree number   5, Training L2 error: 0.0045731707, Validation L2 error: 0.9024390244, Elapsed time: 0:00:00.786345
# Training finished. Elapsed time: 0:00:04.111720
#
# Participant: participant_75, at fold_idx 3 with RMSE: 1.0220734544745125
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0015243902, Validation L2 error: 0.4878048780, Elapsed time: 0:00:00.726887
# Tree number   2, Training L2 error: 0.0213414634, Validation L2 error: 0.7865853659, Elapsed time: 0:00:00.804225
# Tree number   3, Training L2 error: 0.0106707317, Validation L2 error: 0.4878048780, Elapsed time: 0:00:00.708494
# Tree number   4, Training L2 error: 0.0060975610, Validation L2 error: 1.5182926829, Elapsed time: 0:00:00.769523
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 0.6036585366, Elapsed time: 0:00:00.755611
# Training finished. Elapsed time: 0:00:03.764740
#
# Participant: participant_75, at fold_idx 4 with RMSE: 0.6291690222321703
#
# 5-Fold CV for participant: participant_87
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0000000000, Validation L2 error: 4.0975609756, Elapsed time: 0:00:00.789504
# Tree number   2, Training L2 error: 0.0000000000, Validation L2 error: 0.2682926829, Elapsed time: 0:00:00.815239
# Tree number   3, Training L2 error: 0.0198170732, Validation L2 error: 0.9451219512, Elapsed time: 0:00:00.772847
# Tree number   4, Training L2 error: 0.0000000000, Validation L2 error: 0.1585365854, Elapsed time: 0:00:00.787739
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 0.5548780488, Elapsed time: 0:00:00.804984
# Training finished. Elapsed time: 0:00:03.970313
#
# Participant: participant_87, at fold_idx 0 with RMSE: 0.7057257119361636
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0000000000, Validation L2 error: 5.4329268293, Elapsed time: 0:00:00.755205
# Tree number   2, Training L2 error: 0.0000000000, Validation L2 error: 0.4817073171, Elapsed time: 0:00:00.794633
# Tree number   3, Training L2 error: 0.0000000000, Validation L2 error: 0.4939024390, Elapsed time: 0:00:00.781999
# Tree number   4, Training L2 error: 0.0000000000, Validation L2 error: 0.5182926829, Elapsed time: 0:00:00.801476
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 13.3597560976, Elapsed time: 0:00:00.824747
# Training finished. Elapsed time: 0:00:03.958060
#
# Participant: participant_87, at fold_idx 1 with RMSE: 1.0848176198295651
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0076219512, Validation L2 error: 1.4268292683, Elapsed time: 0:00:00.804403
# Tree number   2, Training L2 error: 0.0000000000, Validation L2 error: 12.2743902439, Elapsed time: 0:00:00.867107
# Tree number   3, Training L2 error: 0.0000000000, Validation L2 error: 11.3902439024, Elapsed time: 0:00:00.823996
# Tree number   4, Training L2 error: 0.0030487805, Validation L2 error: 11.9634146341, Elapsed time: 0:00:00.856483
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 0.5243902439, Elapsed time: 0:00:00.776658
# Training finished. Elapsed time: 0:00:04.128647
#
# Participant: participant_87, at fold_idx 2 with RMSE: 2.105799193632299
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0000000000, Validation L2 error: 2.4878048780, Elapsed time: 0:00:00.791331
# Tree number   2, Training L2 error: 0.0000000000, Validation L2 error: 2.6951219512, Elapsed time: 0:00:00.763374
# Tree number   3, Training L2 error: 0.0000000000, Validation L2 error: 0.4146341463, Elapsed time: 0:00:00.793902
# Tree number   4, Training L2 error: 0.0000000000, Validation L2 error: 22.0000000000, Elapsed time: 0:00:00.807144
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 2.2439024390, Elapsed time: 0:00:00.773000
# Training finished. Elapsed time: 0:00:03.928751
#
# Participant: participant_87, at fold_idx 3 with RMSE: 1.7417400887001957
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0000000000, Validation L2 error: 1.5365853659, Elapsed time: 0:00:00.797791
# Tree number   2, Training L2 error: 0.2240853659, Validation L2 error: 5.8963414634, Elapsed time: 0:00:00.764234
# Tree number   3, Training L2 error: 0.0000000000, Validation L2 error: 1.7378048780, Elapsed time: 0:00:00.842498
# Tree number   4, Training L2 error: 0.0625000000, Validation L2 error: 5.0914634146, Elapsed time: 0:00:00.746278
# Tree number   5, Training L2 error: 0.0000000000, Validation L2 error: 1.9268292683, Elapsed time: 0:00:00.769223
# Training finished. Elapsed time: 0:00:03.920024
#
# Participant: participant_87, at fold_idx 4 with RMSE: 1.057493585288738
#
# Participant: participant_87, got a new best CV score: 1.3391152398773922 with params: {'n_estimators': 5, 'max_depth': 13, 'max_features': 4}
#
# 5-Fold CV for participant: participant_89
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0297256098, Validation L2 error: 1.3993902439, Elapsed time: 0:00:01.471421
# Tree number   2, Training L2 error: 0.0342987805, Validation L2 error: 1.2378048780, Elapsed time: 0:00:01.509845
# Tree number   3, Training L2 error: 0.0487804878, Validation L2 error: 1.0945121951, Elapsed time: 0:00:01.584610
# Tree number   4, Training L2 error: 0.0525914634, Validation L2 error: 1.0396341463, Elapsed time: 0:00:01.391127
# Tree number   5, Training L2 error: 0.0312500000, Validation L2 error: 1.7774390244, Elapsed time: 0:00:01.406970
# Training finished. Elapsed time: 0:00:07.363973
#
# Participant: participant_89, at fold_idx 0 with RMSE: 0.8692581642398081
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0114329268, Validation L2 error: 1.2134146341, Elapsed time: 0:00:01.635846
# Tree number   2, Training L2 error: 0.0137195122, Validation L2 error: 1.0853658537, Elapsed time: 0:00:01.684854
# Tree number   3, Training L2 error: 0.0060975610, Validation L2 error: 1.4756097561, Elapsed time: 0:00:01.456617
# Tree number   4, Training L2 error: 0.0083841463, Validation L2 error: 1.1432926829, Elapsed time: 0:00:01.762568
# Tree number   5, Training L2 error: 0.0304878049, Validation L2 error: 1.4115853659, Elapsed time: 0:00:01.462947
# Training finished. Elapsed time: 0:00:08.002832
#
# Participant: participant_89, at fold_idx 1 with RMSE: 0.9245961544266166
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0167682927, Validation L2 error: 0.8353658537, Elapsed time: 0:00:01.596351
# Tree number   2, Training L2 error: 0.0274390244, Validation L2 error: 1.0975609756, Elapsed time: 0:00:01.414089
# Tree number   3, Training L2 error: 0.0381097561, Validation L2 error: 0.9786585366, Elapsed time: 0:00:01.593756
# Tree number   4, Training L2 error: 0.0144817073, Validation L2 error: 0.8262195122, Elapsed time: 0:00:01.548706
# Tree number   5, Training L2 error: 0.0266768293, Validation L2 error: 1.0762195122, Elapsed time: 0:00:01.471035
# Training finished. Elapsed time: 0:00:07.639559
#
# Participant: participant_89, at fold_idx 2 with RMSE: 0.7130320007870204
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0205792683, Validation L2 error: 0.7713414634, Elapsed time: 0:00:01.447703
# Tree number   2, Training L2 error: 0.0388719512, Validation L2 error: 0.9451219512, Elapsed time: 0:00:01.288809
# Tree number   3, Training L2 error: 0.0525914634, Validation L2 error: 0.6707317073, Elapsed time: 0:00:01.428136
# Tree number   4, Training L2 error: 0.0190548780, Validation L2 error: 0.8384146341, Elapsed time: 0:00:01.545984
# Tree number   5, Training L2 error: 0.0289634146, Validation L2 error: 0.7896341463, Elapsed time: 0:00:01.555424
# Training finished. Elapsed time: 0:00:07.281676
#
# Participant: participant_89, at fold_idx 3 with RMSE: 0.6381184231404228
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0388719512, Validation L2 error: 1.5213414634, Elapsed time: 0:00:01.336298
# Tree number   2, Training L2 error: 0.0236280488, Validation L2 error: 1.9237804878, Elapsed time: 0:00:01.446256
# Tree number   3, Training L2 error: 0.0304878049, Validation L2 error: 1.5060975610, Elapsed time: 0:00:01.538508
# Tree number   4, Training L2 error: 0.0373475610, Validation L2 error: 1.1524390244, Elapsed time: 0:00:01.248963
# Tree number   5, Training L2 error: 0.0556402439, Validation L2 error: 1.0945121951, Elapsed time: 0:00:01.428932
# Training finished. Elapsed time: 0:00:06.998957
#
# Participant: participant_89, at fold_idx 4 with RMSE: 1.0606601717798212
#
# 5-Fold CV for participant: participant_96
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0091463415, Validation L2 error: 4.8682926829, Elapsed time: 0:00:02.157434
# Tree number   2, Training L2 error: 0.0329268293, Validation L2 error: 3.0414634146, Elapsed time: 0:00:01.853188
# Tree number   3, Training L2 error: 0.0262195122, Validation L2 error: 2.4268292683, Elapsed time: 0:00:02.022022
# Tree number   4, Training L2 error: 0.0554878049, Validation L2 error: 3.5609756098, Elapsed time: 0:00:02.186081
# Tree number   5, Training L2 error: 0.0353658537, Validation L2 error: 4.8731707317, Elapsed time: 0:00:02.136314
# Training finished. Elapsed time: 0:00:10.355039
#
# Participant: participant_96, at fold_idx 0 with RMSE: 1.0838054005869613
#
# Model parameters:
# {'min_split_gain': 0.0, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'max_features': 4}
# Training started...
# Tree number   1, Training L2 error: 0.0658536585, Validation L2 error: 1.8317073171, Elapsed time: 0:00:01.924268
# Participant: participant_96, at fold_idx 4 with RMSE: 0.9561100048966199
#
# CV finished. Elapsed time: 1:21:44.498356

# %%
# Uncomment to launch Cross validation

# best_CV_info = launch_IREN_VFoldCV(training_df, params,
#                         u_participants, num_folds=5)

# %% [markdown]
# The list of the best parameters for each regression model is shown together with the corresponding RMSE.

# %%
global_rmse = 0
for participant, CV_info in best_CV_info.items():
    global_rmse += CV_info.score
    print (participant, CV_info.params, CV_info.score)
    
print('Global RMSE: {:3f}'.format(global_rmse/len(best_CV_info.items())))
# Out:
# participant_116 {'n_estimators': 5, 'max_depth': 7} 0.6929994727698511
# participant_120 {'n_estimators': 5, 'max_depth': 7} 0.5167813089032119
# participant_146 {'n_estimators': 5, 'max_depth': 13, 'max_features': 4} 0.7412603526365011
# participant_158 {'n_estimators': 5, 'max_depth': 13, 'max_features': 4} 0.6842460464581757
# participant_176 {'n_estimators': 5, 'max_depth': 7} 0.5447924411163483
# participant_21 {'n_estimators': 5, 'max_depth': 7} 0.40557378944566064
# participant_60 {'n_estimators': 5, 'max_depth': 7} 0.44825118284436005
# participant_75 {'n_estimators': 5, 'max_depth': 7, 'max_features': 4} 0.8177611977540428
# participant_87 {'n_estimators': 5, 'max_depth': 13, 'max_features': 4} 1.3391152398773922
# participant_89 {'n_estimators': 5, 'max_depth': 10, 'max_features': 4} 0.8655632195053073
# participant_96 {'n_estimators': 5, 'max_depth': 10, 'max_features': 4} 1.457784792855071
# Global RMSE: 0.774012

# %%
# Save the file
import pickle

with open('best_CV_info.pickle', 'wb') as f:
    pickle.dump(best_CV_info, f)

# %% [markdown]
# Using the best models for each participant, the prediction for the test set is computed.

# %%
import gc

# Load test set
test_X_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_X.csv', index_col='date', header=0, sep=';')
test_Y_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_Y.csv', index_col='date', header=0, sep=';')

# Encode technology according to the already used encoding scheme
test_X_df.technology = enc_technologies.transform(test_X_df.technology)

# Columns to be dropped from the input of test set
out_features=['date', 'participant']

# Number of folds used in V-Fold CV
num_folds = 5

# Init of the array containing the predictions
test_Y_pred = []

# for each regression model (for each participant)
for participant in best_CV_info.keys():
    print("Extracting {}'s data...".format(participant.capitalize()))

    # Extract the current participant
    X_test_Participant = test_X_df.loc[test_X_df.participant
                                == participant].reset_index()
    
    # Collect dates in X
    X_test_Participant_date = X_test_Participant.date

    # Drop the specified columns from the test set input
    X_test_Participant.drop(columns=out_features, inplace=True)
    
    # Init array of prediction for the current participant
    Y_pred_test_Participant = np.zeros(X_test_Participant.shape[0])
    
    test_single_Y_df = None
    
    # for each model of the current participant
    for fold_idx in range(num_folds):
        
        # extract the current model
        model_RF = best_CV_info[participant].models[fold_idx]
        
        # Accumulate predictions
        Y_pred_test_Participant += model_RF.predict(X_test_Participant.to_numpy())
        
        gc.collect()
        
    # Get a mean of the prediction of the models, cast to the nearest integer                   
    Y_pred_test_Participant = (np.round(Y_pred_test_Participant / num_folds)).astype(int)
    
    # Build a dataframe containing the predictions for a single participant
    test_single_Y_df = pd.DataFrame({'technology': enc_technologies.inverse_transform(
                                            X_test_Participant.technology),
                            'date': X_test_Participant_date, 'participant': participant,
                            'n_acc_offers': Y_pred_test_Participant})
    
    # Append the dataframe
    test_Y_pred.append(test_single_Y_df)
    
    print("{} scoring is completed\n".format(participant.capitalize()))
    gc.collect()

# Create the final dataframe
test_Y_pred_df = pd.concat(test_Y_pred)
# Out:
# Extracting Participant_116's data...
# Participant_116 scoring is completed
#
# Extracting Participant_120's data...
# Participant_120 scoring is completed
#
# Extracting Participant_146's data...
# Participant_146 scoring is completed
#
# Extracting Participant_158's data...
# Participant_158 scoring is completed
#
# Extracting Participant_176's data...
# Participant_176 scoring is completed
#
# Extracting Participant_21's data...
# Participant_21 scoring is completed
#
# Extracting Participant_60's data...
# Participant_60 scoring is completed
#
# Extracting Participant_75's data...
# Participant_75 scoring is completed
#
# Extracting Participant_87's data...
# Participant_87 scoring is completed
#
# Extracting Participant_89's data...
# Participant_89 scoring is completed
#
# Extracting Participant_96's data...
# Participant_96 scoring is completed

# %% [markdown]
# A global performance is computed.

# %%
print('Test RMSE error with RF: {}'.format(np.sqrt(calculate_MSE(
            test_Y_df.n_acc_offers.to_numpy(), test_Y_pred_df.n_acc_offers.to_numpy()))))
# Out:
# Test RMSE error with RF: 0.6018678409411685

# %% [markdown]
# The RMSE for each (`participant`,`technology`) is computed and shown. The plots of all the forecasted time series is provided vs the ground truth.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams.update({'figure.max_open_warning': 50})

for i, pair in enumerate(unique_pairs):
    
    current_df_true = test_Y_df.n_acc_offers[(test_Y_df['participant'] == pair[0]) & (test_Y_df['technology'] == pair[1])]
    current_df_pred = test_Y_pred_df.n_acc_offers[(test_Y_pred_df['participant'] == pair[0]) & (test_Y_pred_df['technology'] == pair[1])]
    
    true = current_df_true.to_numpy()
    pred = current_df_pred.to_numpy()
    loss = np.sqrt(calculate_MSE(true,pred))
    
    print(pair[0],pair[1],loss)
    
    plt.figure(i,figsize=(15,3))
    plt.plot(current_df_true.index,true,label='True',ls=':')
    plt.plot(current_df_true.index,pred,label='Prediction')
    plt.legend()
    plt.title('{} {}: RMSE {:5f}'.format(pair[0],pair[1],loss))
# Out:
# participant_116 ccgt 0.0
# participant_116 ccgt400 0.6546536707079771
# participant_116 ccgt800 0.7559289460184544
# participant_116 pump 0.0
# participant_116 reservoir 0.0
# participant_120 ccgt800 0.0
# participant_146 pump 0.5345224838248488
# participant_146 reservoir 0.9258200997725514
# participant_158 ccgt400 0.0
# participant_158 ccgt800 0.7559289460184544
# participant_158 pump 0.5345224838248488
# participant_158 reservoir 0.0
# participant_176 ccgt800 0.0
# participant_21 reservoir 0.0
# participant_60 ccgt400 0.0
# participant_75 ccgt400 0.9258200997725514
# participant_75 ccgt800 0.8451542547285166
# participant_87 ccgt 0.3779644730092272
# participant_87 ccgt400 0.0
# participant_89 ccgt400 1.1338934190276817
# participant_89 ccgt800 0.3779644730092272
# participant_89 coal 0.0
# participant_89 reservoir 0.0
# participant_96 ccgt400 0.3779644730092272
# participant_96 ccgt800 0.9258200997725514
# participant_96 coal 0.6546536707079771
# participant_96 pump 0.9258200997725514
# participant_96 reservoir 1.3093073414159542

# %% [markdown]
# #### Gradient Boosting (by Federico Minutoli)
#
# The implementation of Gradient Boosting is included in the folder <i>gradboosting/src</i>:
#
# - <i>decision_tree.py</i> contains the classes:
#     - `Tree` which models a regression tree
#     - `Node` which models a single node of the tree and contains the function `build` used to grow the regression tree according to the greedy solution inspired by XGBoost described in Section 4 of the report
#
#
# - <i>gbm.py</i> contains the class `GBDT` used to create the gradient boosting machine
#
#
# - <i>utils.py</i> contains a set of helpers functions: <i>calculate_MSE</i> to compute the Mean Square Error (MSE) whenever needed, *choose_CV_params* which is a generator of parameters' combinations given various lists, that was extensively used for V-Fold CV and the simple container class *Dataset* which groups an X and a Y, mimicking LightGBM's one
#
# - <i>combinats_CV_params.py</i> is an helper script, which given a predetermined dict of possible parameters generates the desired amount of combinations and dumps to file as Pickle objects

# %% [markdown]
# Moreover on *V-Fold CV*, opting for a grid search solution was unfeasible. Indeed, by having approximately $6^5$ (5 values for each parameter) different combinations to try it would have taken over *12 years* unless some of the Gradient Boosting Machines stopped early due to the `early_stopping_round` metaparameter. Hence, I followed a random search approach which cut the combinatory space to a computable amount. This was especially crucial to launch batch jobs which ran V-Fold CV on the remote **FarmUI** cluster, as it was the only way to effectively try different combinations in a reasonable time.

# %%
import numpy as np
import pandas as pd
import sys

# Custom imports
from gradboosting.src.gbm   import GBDT
from gradboosting.src.utils import calculate_MSE

# %% [markdown]
# For the sake of simplicity the 5-Fold Cross Validation is executed with a 3 fixed combinations of parameters, just to demonstrate its purpose and functionality. A single round of cross-validation using the *Divide and conquer* approach should take somewhere around 15 minutes.
#
# The parameters used are:
#
# - `gamma`: the penalty associated to the increasing number of leaves in the tree
# - `lambda`: the regularization paramter used in the objective function
# - `learning_rate`: the shrinkage rate applied to the weights at each boosting round
# - `max_depth`: the max number of levels the tree can grow into
# - `max_features`: the percentage of random features to consider when subsampling looking for the best split
# - `min_split_gain`: the minimum information gain a split can provide to be considered valid
#
# `min_samples_leaf` and `min_samples_split` were fixed to 1 and 2 and thus are not part of the cross-validation discussion.

# %%
# # Uncomment the following lines to directly load the best models
# # per-participant generated on FarmUI and skip CV execution

# import pickle

# with open('./best_CV_info_GBM.pickle','rb') as f:
#      best_CV_info_GBM = pickle.load(f)

# %%
# Custom helper class
from gradboosting.src.utils import Dataset

from sklearn.model_selection import KFold

def launch_IREN_VFoldCV_GBM(training_df, params_combinats,
                            participants, seed=None, num_folds=5,
                            early_stopping_rounds=16,
                            out_features=['n_acc_offers', 'participant']):
    
    """
    Execute V-Fold CV tuned for IREN case study
    
    Parameters
    ------------
    training_df: Pandas dataframe
    Training set X
    
    params_combinats: list of dictionaries
    List of parameters combinations to be cross-validated
    
    participants: list
    List of participants given by IREN
    
    seed: int [default=None]
    If None non-repeatable fold split is executed
    
    num_folds: int [default=5]
    Number of folds for V-Fold CV
    
    early_stopping_rounds: int [default=16]
    Number of boosting rounds (CART models) in sequence
    among which the validation loss doesn't improve.
    
    This parameter is especially crucial, since a common
    procedure is to let num_boost_rounds be as high as
    you want and control the growth of the CART trees
    with a combination of early_stopping_rounds and
    learning_rate which should be inversely
    proportionale to avoid overfitting.
    
    out_features: list
    Columns to be dropped in the validation fold
    for the prediction
    
    """
    
    from datetime import datetime
    CV_start_time = datetime.now()
    
    # Output CV info per participant 
    best_CV_info = {}

    for participant in participants:
        best_CV_info[participant] = CVInfo()
        
    for params in params_combinats:
        print('Testing CV with params:', params)
        current_GBDT_models = {}

        for participant in participants:
            print("{}-Fold CV for participant:".format(num_folds), participant)

            KF_generator = KFold(n_splits=num_folds, random_state=seed)
            current_GBDT_models[participant] = []
            
            # # Divide and Conquer strategy
            # Extract information on a single participant

            X_train_Participant = training_df.loc[training_df.participant
                                        == participant].reset_index(drop=True)

            Y_train_Participant = X_train_Participant.n_acc_offers
            Y_pred_train_Participant = np.zeros(X_train_Participant.shape[0])

            X_train_Participant.drop(columns=out_features, inplace=True)

            CV_score = 0

            # Fit the CART learners on the current fold
            for fold_idx, (train_idx, valid_idx) in enumerate(
                                KF_generator.split(X_train_Participant, Y_train_Participant)):

                X_train, X_valid = X_train_Participant.loc[train_idx].to_numpy(), \
                        X_train_Participant.loc[valid_idx].to_numpy()

                Y_train, Y_valid = Y_train_Participant.iloc[train_idx].to_numpy(), \
                        Y_train_Participant.iloc[valid_idx].to_numpy()

                # early_stopping_rounds has been set to as low as 4
                # to make CV doable in a decent time. Hence, I was able
                # to interpret results over many combinations.
                model_GBDT = GBDT()
                model_GBDT.train(params, Dataset(X_train, Y_train), num_boost_round=1024,
                                    validation_set=Dataset(X_valid, Y_valid),
                                    early_stopping_rounds=early_stopping_rounds)

                current_GBDT_models[participant].append(model_GBDT)
                    
                Y_pred_valid = model_GBDT.predict(X_valid,
                            num_iterations=model_GBDT.best_iteration)

                valid_RMSE = np.sqrt(calculate_MSE(Y_valid, Y_pred_valid))
                # print("Participant: {}, at fold_idx {} with RMSE: {}\n" \
                #              .format(participant, fold_idx, valid_RMSE))

                CV_score += valid_RMSE / num_folds

            if best_CV_info[participant].check_score(CV_score,
                        current_GBDT_models[participant], params):
                print('Participant: {}, got a new best CV score: {} with params: {}\n' \
                                  .format(participant, CV_score, params))
    
    print('CV finished. Elapsed time: {}' \
                .format(datetime.now() - CV_start_time))
            
    return best_CV_info

# %%
# Set of parameters for on premises V-Fold CV

params_combinats = [
    {
        'gamma': 0.3,
        'lambda': 1.0,
        'learning_rate': 0.05,
        'max_depth': 5,
        'max_features': 0.33,
        'min_split_gain': 0.5
    },
    {
        'gamma': 0.1, 
        'lambda': 0.3,
        'learning_rate': 0.1,
        'max_depth': 3,
        'max_features': 0.50,
        'min_split_gain': 0.1
    },
    {
        'gamma': 0.3,
        'lambda': 1.0,
        'learning_rate': 0.01,
        'max_depth': 5,
        'max_features': 0.33,
        'min_split_gain': 0.3
    }
]

best_CV_info_GBM = launch_IREN_VFoldCV_GBM(training_df, params_combinats,
                            u_participants, early_stopping_rounds=16)
# Out:
# Testing CV with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# 5-Fold CV for participant: participant_116
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.0962940000, Validation L2 error: 0.2289680000, Elapsed time: 0:00:00.740105
# Iteration   8, Training L2 error: 0.0851830000, Validation L2 error: 1.1580970000, Elapsed time: 0:00:00.765444
# Iteration  16, Training L2 error: 0.0851830000, Validation L2 error: 1.1580970000, Elapsed time: 0:00:00.847101
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 1.1580910000
# Training finished. Elapsed time: 0:00:15.917958
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.9501810000, Validation L2 error: 3.0995490000, Elapsed time: 0:00:00.663610
# Iteration   8, Training L2 error: 0.0487830000, Validation L2 error: 0.8499140000, Elapsed time: 0:00:00.749800
# Iteration  16, Training L2 error: 0.0487830000, Validation L2 error: 0.8499140000, Elapsed time: 0:00:00.846726
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 0.8499130000
# Training finished. Elapsed time: 0:00:17.279286
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.4344530000, Validation L2 error: 1.2887160000, Elapsed time: 0:00:00.614435
# Iteration   8, Training L2 error: 0.0566240000, Validation L2 error: 0.0576690000, Elapsed time: 0:00:00.744754
# Iteration  16, Training L2 error: 0.0566240000, Validation L2 error: 0.0576690000, Elapsed time: 0:00:00.775366
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.0576650000
# Training finished. Elapsed time: 0:00:13.430735
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.4423960000, Validation L2 error: 0.9697780000, Elapsed time: 0:00:00.657683
# Iteration   8, Training L2 error: 0.0819940000, Validation L2 error: 0.1808900000, Elapsed time: 0:00:00.756749
# Iteration  16, Training L2 error: 0.0819940000, Validation L2 error: 0.1808900000, Elapsed time: 0:00:00.820631
# Early stopping. Best iteration is:
# Iteration   4, Training's L2 error: 0.1808900000
# Training finished. Elapsed time: 0:00:16.195048
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.9312440000, Validation L2 error: 3.5933540000, Elapsed time: 0:00:00.635932
# Iteration   8, Training L2 error: 0.0371870000, Validation L2 error: 0.9990140000, Elapsed time: 0:00:00.721258
# Iteration  16, Training L2 error: 0.0371870000, Validation L2 error: 0.9990140000, Elapsed time: 0:00:00.693446
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.9978640000
# Training finished. Elapsed time: 0:00:12.649008
#
# Participant: participant_116, got a new best CV score: 0.9119216628586337 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_120
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.4228970000, Validation L2 error: 0.5933850000, Elapsed time: 0:00:00.132243
# Iteration   1, Training's L2 error: 0.5245200000
# Training finished. Elapsed time: 0:00:05.657860
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.8513680000, Validation L2 error: 1.7846280000, Elapsed time: 0:00:00.288035
# Iteration   8, Training L2 error: 0.2546340000, Validation L2 error: 0.5121790000, Elapsed time: 0:00:00.312424
# Iteration  16, Training L2 error: 0.2546340000, Validation L2 error: 0.5121790000, Elapsed time: 0:00:00.328045
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.5001340000
# Training finished. Elapsed time: 0:00:05.728606
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.9162600000, Validation L2 error: 2.9672710000, Elapsed time: 0:00:00.290894
# Iteration   8, Training L2 error: 0.1566980000, Validation L2 error: 0.7613820000, Elapsed time: 0:00:00.374876
# Iteration  16, Training L2 error: 0.1566980000, Validation L2 error: 0.7613820000, Elapsed time: 0:00:00.328043
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.7609790000
# Training finished. Elapsed time: 0:00:05.629721
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.6152310000, Validation L2 error: 2.0554430000, Elapsed time: 0:00:00.281184
# Iteration   8, Training L2 error: 0.2048270000, Validation L2 error: 0.4433700000, Elapsed time: 0:00:00.312425
# Iteration  16, Training L2 error: 0.2048270000, Validation L2 error: 0.4433700000, Elapsed time: 0:00:00.343667
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.4433430000
# Training finished. Elapsed time: 0:00:05.937764
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.9721620000, Validation L2 error: 1.8655060000, Elapsed time: 0:00:00.288272
# Iteration   8, Training L2 error: 0.3219090000, Validation L2 error: 0.9954790000, Elapsed time: 0:00:00.312431
# Iteration  16, Training L2 error: 0.3219090000, Validation L2 error: 0.9954790000, Elapsed time: 0:00:00.328048
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.9923410000
# Training finished. Elapsed time: 0:00:05.824738
#
# Participant: participant_146, got a new best CV score: 1.3088900572624356 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_158
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.1434430000, Validation L2 error: 2.4271290000, Elapsed time: 0:00:00.615378
# Iteration   8, Training L2 error: 0.1525480000, Validation L2 error: 0.8334350000, Elapsed time: 0:00:00.626190
# Iteration  16, Training L2 error: 0.1525480000, Validation L2 error: 0.8334350000, Elapsed time: 0:00:00.734171
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.8285970000
# Training finished. Elapsed time: 0:00:11.370243
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.0002570000, Validation L2 error: 1.3188970000, Elapsed time: 0:00:00.569701
# Iteration   8, Training L2 error: 0.3635240000, Validation L2 error: 1.3868660000, Elapsed time: 0:00:00.624859
# Iteration  16, Training L2 error: 0.3635240000, Validation L2 error: 1.3868660000, Elapsed time: 0:00:00.671715
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 1.3868660000
# Training finished. Elapsed time: 0:00:13.999120
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.2151740000, Validation L2 error: 2.0547000000, Elapsed time: 0:00:00.820170
# Iteration   8, Training L2 error: 0.1644210000, Validation L2 error: 0.4585530000, Elapsed time: 0:00:00.732923
# Iteration  16, Training L2 error: 0.1644210000, Validation L2 error: 0.4585530000, Elapsed time: 0:00:00.683857
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 0.4585530000
# Training finished. Elapsed time: 0:00:14.325781
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.8661050000, Validation L2 error: 2.2692740000, Elapsed time: 0:00:00.547860
# Iteration   8, Training L2 error: 0.1339420000, Validation L2 error: 0.5530870000, Elapsed time: 0:00:00.610281
# Iteration  16, Training L2 error: 0.1339420000, Validation L2 error: 0.5530870000, Elapsed time: 0:00:00.656096
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.5510370000
# Training finished. Elapsed time: 0:00:11.227590
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.4704640000, Validation L2 error: 2.5046100000, Elapsed time: 0:00:00.570041
# Iteration   8, Training L2 error: 0.1735600000, Validation L2 error: 0.8485620000, Elapsed time: 0:00:00.775613
# Iteration  16, Training L2 error: 0.1735600000, Validation L2 error: 0.8485620000, Elapsed time: 0:00:00.663570
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 0.8485200000
# Training finished. Elapsed time: 0:00:13.266115
#
# Participant: participant_158, got a new best CV score: 1.1680836980388396 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_176
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.4016410000, Validation L2 error: 1.3722730000, Elapsed time: 0:00:00.112187
# Iteration   8, Training L2 error: 0.0430610000, Validation L2 error: 0.6221280000, Elapsed time: 0:00:00.124972
# Iteration  16, Training L2 error: 0.0430610000, Validation L2 error: 0.6221280000, Elapsed time: 0:00:00.093726
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 0.6221280000
# Training finished. Elapsed time: 0:00:02.649765
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.8496100000, Validation L2 error: 0.3423650000, Elapsed time: 0:00:00.111226
# Iteration   8, Training L2 error: 0.0714610000, Validation L2 error: 0.4338120000, Elapsed time: 0:00:00.159081
# Iteration  16, Training L2 error: 0.0714610000, Validation L2 error: 0.4338120000, Elapsed time: 0:00:00.140595
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.4325520000
# Training finished. Elapsed time: 0:00:02.512446
#
# Training until validation scores don't improve for 16 rounds.
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.1349390000
# Training finished. Elapsed time: 0:00:02.001042
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.8440540000, Validation L2 error: 0.8471990000, Elapsed time: 0:00:00.078106
# Iteration   8, Training L2 error: 0.0158860000, Validation L2 error: 0.3054830000, Elapsed time: 0:00:00.029233
# Iteration  16, Training L2 error: 0.0158860000, Validation L2 error: 0.3054830000, Elapsed time: 0:00:00.031243
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.3054600000
# Training finished. Elapsed time: 0:00:00.589019
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.7730990000, Validation L2 error: 0.8278820000, Elapsed time: 0:00:00.079224
# Iteration   8, Training L2 error: 0.0423530000, Validation L2 error: 0.0588820000, Elapsed time: 0:00:00.078108
# Iteration  16, Training L2 error: 0.0423530000, Validation L2 error: 0.0588820000, Elapsed time: 0:00:00.122022
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.0588810000
# Training finished. Elapsed time: 0:00:01.547209
#
# Participant: participant_21, got a new best CV score: 0.7105163300850751 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_60
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.7779360000, Validation L2 error: 5.5258250000, Elapsed time: 0:00:00.140592
# Iteration   8, Training L2 error: 0.0277590000, Validation L2 error: 0.3921060000, Elapsed time: 0:00:00.089893
# Iteration  16, Training L2 error: 0.0277590000, Validation L2 error: 0.3921060000, Elapsed time: 0:00:00.078108
# Early stopping. Best iteration is:
# Iteration   4, Training's L2 error: 0.3921060000
# Training finished. Elapsed time: 0:00:01.904176
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.8960400000, Validation L2 error: 3.2961620000, Elapsed time: 0:00:00.093726
# Iteration   8, Training L2 error: 0.0172290000, Validation L2 error: 0.2725270000, Elapsed time: 0:00:00.029457
# Iteration  16, Training L2 error: 0.0172290000, Validation L2 error: 0.2725270000, Elapsed time: 0:00:00.063502
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.2721600000
# Training finished. Elapsed time: 0:00:01.092874
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 4.0321860000, Validation L2 error: 3.8393770000, Elapsed time: 0:00:00.146842
# Iteration   8, Training L2 error: 0.0766850000, Validation L2 error: 0.2439230000, Elapsed time: 0:00:00.142257
# Iteration  16, Training L2 error: 0.0766850000, Validation L2 error: 0.2439230000, Elapsed time: 0:00:00.156215
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 0.2439120000
# Training finished. Elapsed time: 0:00:02.960534
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.6009860000, Validation L2 error: 3.6225200000, Elapsed time: 0:00:00.146429
# Iteration   8, Training L2 error: 0.0395700000, Validation L2 error: 0.0497300000, Elapsed time: 0:00:00.125174
# Iteration  16, Training L2 error: 0.0395700000, Validation L2 error: 0.0497300000, Elapsed time: 0:00:00.078073
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.0492420000
# Training finished. Elapsed time: 0:00:01.711408
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.7559960000, Validation L2 error: 3.6814360000, Elapsed time: 0:00:00.127823
# Iteration   8, Training L2 error: 0.0578660000, Validation L2 error: 0.1223260000, Elapsed time: 0:00:00.078107
# Iteration  16, Training L2 error: 0.0578660000, Validation L2 error: 0.1223260000, Elapsed time: 0:00:00.109317
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.1222970000
# Training finished. Elapsed time: 0:00:02.108778
#
# Participant: participant_60, got a new best CV score: 1.0377869446756847 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_75
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 8.1396460000, Validation L2 error: 2.2031010000, Elapsed time: 0:00:00.299457
# Iteration   8, Training L2 error: 0.4227570000, Validation L2 error: 1.0111070000, Elapsed time: 0:00:00.331397
# Iteration  16, Training L2 error: 0.4227570000, Validation L2 error: 1.0111070000, Elapsed time: 0:00:00.328050
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 1.0111070000
# Training finished. Elapsed time: 0:00:07.248982
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 7.4814630000, Validation L2 error: 2.8086580000, Elapsed time: 0:00:00.306570
# Iteration   8, Training L2 error: 0.2561170000, Validation L2 error: 2.8658530000, Elapsed time: 0:00:00.318127
# Iteration  16, Training L2 error: 0.2561170000, Validation L2 error: 2.8658530000, Elapsed time: 0:00:00.351630
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 2.8457040000
# Training finished. Elapsed time: 0:00:05.853298
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.4277680000, Validation L2 error: 2.8055970000, Elapsed time: 0:00:00.293928
# Iteration   8, Training L2 error: 0.2255310000, Validation L2 error: 1.3290810000, Elapsed time: 0:00:00.296806
# Iteration  16, Training L2 error: 0.2255310000, Validation L2 error: 1.3290810000, Elapsed time: 0:00:00.328047
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 1.3290230000
# Training finished. Elapsed time: 0:00:06.016905
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.9719480000, Validation L2 error: 3.1024350000, Elapsed time: 0:00:00.298643
# Iteration   8, Training L2 error: 0.1823750000, Validation L2 error: 0.9011290000, Elapsed time: 0:00:00.362846
# Iteration  16, Training L2 error: 0.1823750000, Validation L2 error: 0.9011290000, Elapsed time: 0:00:00.353227
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.8989540000
# Training finished. Elapsed time: 0:00:05.985645
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.6141160000, Validation L2 error: 2.8807630000, Elapsed time: 0:00:00.304830
# Iteration   8, Training L2 error: 0.2348560000, Validation L2 error: 0.6410710000, Elapsed time: 0:00:00.327245
# Iteration  16, Training L2 error: 0.2348560000, Validation L2 error: 0.6410710000, Elapsed time: 0:00:00.328049
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.6380490000
# Training finished. Elapsed time: 0:00:05.835076
#
# Participant: participant_75, got a new best CV score: 1.4595825910004208 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_87
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 12.1405810000, Validation L2 error: 9.4674090000, Elapsed time: 0:00:00.259462
# Iteration   8, Training L2 error: 0.1925590000, Validation L2 error: 0.3022730000, Elapsed time: 0:00:00.302123
# Iteration  16, Training L2 error: 0.1925590000, Validation L2 error: 0.3022730000, Elapsed time: 0:00:00.342878
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.3001790000
# Training finished. Elapsed time: 0:00:05.469146
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 12.5367530000, Validation L2 error: 8.3239230000, Elapsed time: 0:00:00.247702
# Iteration   8, Training L2 error: 0.2055130000, Validation L2 error: 15.0404390000, Elapsed time: 0:00:00.308173
# Iteration  16, Training L2 error: 0.2055130000, Validation L2 error: 15.0404390000, Elapsed time: 0:00:00.334559
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 15.0294940000
# Training finished. Elapsed time: 0:00:05.641353
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 8.5300940000, Validation L2 error: 11.6628910000, Elapsed time: 0:00:00.355554
# Iteration   8, Training L2 error: 0.3173460000, Validation L2 error: 1.0646120000, Elapsed time: 0:00:00.320992
# Iteration  16, Training L2 error: 0.3173460000, Validation L2 error: 1.0646120000, Elapsed time: 0:00:00.328046
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.0613850000
# Training finished. Elapsed time: 0:00:05.695868
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 4.7634310000, Validation L2 error: 5.4583660000, Elapsed time: 0:00:00.249942
# Iteration   8, Training L2 error: 0.1491700000, Validation L2 error: 0.3608030000, Elapsed time: 0:00:00.307701
# Iteration  16, Training L2 error: 0.1491700000, Validation L2 error: 0.3608030000, Elapsed time: 0:00:00.421807
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.3600960000
# Training finished. Elapsed time: 0:00:05.572379
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 5.3902140000, Validation L2 error: 3.9644640000, Elapsed time: 0:00:00.240356
# Iteration   8, Training L2 error: 0.1484530000, Validation L2 error: 1.2630910000, Elapsed time: 0:00:00.317683
# Iteration  16, Training L2 error: 0.1484530000, Validation L2 error: 1.2630910000, Elapsed time: 0:00:00.328018
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.2607750000
# Training finished. Elapsed time: 0:00:05.467847
#
# Participant: participant_87, got a new best CV score: 2.740908939107856 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_89
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.9507490000, Validation L2 error: 2.7736500000, Elapsed time: 0:00:00.554067
# Iteration   8, Training L2 error: 0.4310790000, Validation L2 error: 0.6990730000, Elapsed time: 0:00:00.635267
# Iteration  16, Training L2 error: 0.4310790000, Validation L2 error: 0.6990730000, Elapsed time: 0:00:00.673112
# Early stopping. Best iteration is:
# Iteration   4, Training's L2 error: 0.6990730000
# Training finished. Elapsed time: 0:00:13.681467
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.6163410000, Validation L2 error: 4.9042520000, Elapsed time: 0:00:00.638165
# Iteration   8, Training L2 error: 0.2748110000, Validation L2 error: 0.9936980000, Elapsed time: 0:00:00.645384
# Iteration  16, Training L2 error: 0.2748110000, Validation L2 error: 0.9936980000, Elapsed time: 0:00:00.850835
# Early stopping. Best iteration is:
# Iteration   4, Training's L2 error: 0.9936980000
# Training finished. Elapsed time: 0:00:13.732007
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.4124660000, Validation L2 error: 3.9319410000, Elapsed time: 0:00:00.595353
# Iteration   8, Training L2 error: 0.3750830000, Validation L2 error: 0.8856000000, Elapsed time: 0:00:00.648419
# Iteration  16, Training L2 error: 0.3750830000, Validation L2 error: 0.8856000000, Elapsed time: 0:00:00.686956
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 0.8856000000
# Training finished. Elapsed time: 0:00:15.027087
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.9682590000, Validation L2 error: 3.1721740000, Elapsed time: 0:00:00.573325
# Iteration   8, Training L2 error: 0.3340400000, Validation L2 error: 0.2853500000, Elapsed time: 0:00:00.624853
# Iteration  16, Training L2 error: 0.3340400000, Validation L2 error: 0.2853500000, Elapsed time: 0:00:00.694097
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 0.2844740000
# Training finished. Elapsed time: 0:00:11.449986
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.2098710000, Validation L2 error: 5.0935540000, Elapsed time: 0:00:00.726369
# Iteration   8, Training L2 error: 0.3236570000, Validation L2 error: 1.0635150000, Elapsed time: 0:00:00.775360
# Iteration  16, Training L2 error: 0.3236570000, Validation L2 error: 1.0635150000, Elapsed time: 0:00:00.656093
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.0615560000
# Training finished. Elapsed time: 0:00:11.627051
#
# Participant: participant_89, got a new best CV score: 1.3623949895175045 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# 5-Fold CV for participant: participant_96
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 4.1796460000, Validation L2 error: 6.2047970000, Elapsed time: 0:00:00.663559
# Iteration   8, Training L2 error: 0.5310160000, Validation L2 error: 2.5209400000, Elapsed time: 0:00:00.777855
# Iteration  16, Training L2 error: 0.5310160000, Validation L2 error: 2.5209400000, Elapsed time: 0:00:00.857123
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 2.5209400000
# Training finished. Elapsed time: 0:00:17.930131
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 6.6515910000, Validation L2 error: 1.1401530000, Elapsed time: 0:00:00.704976
# Iteration   8, Training L2 error: 0.7263290000, Validation L2 error: 2.8813050000, Elapsed time: 0:00:00.781090
# Iteration  16, Training L2 error: 0.7263290000, Validation L2 error: 2.8813050000, Elapsed time: 0:00:00.827930
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 2.8463040000
# Training finished. Elapsed time: 0:00:14.418355
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.7731500000, Validation L2 error: 7.2963710000, Elapsed time: 0:00:00.674648
# Iteration   8, Training L2 error: 0.3788490000, Validation L2 error: 4.4623740000, Elapsed time: 0:00:00.843514
# Iteration  16, Training L2 error: 0.3788490000, Validation L2 error: 4.4623740000, Elapsed time: 0:00:00.833762
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 4.4623740000
# Training finished. Elapsed time: 0:00:17.951801
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 5.9450450000, Validation L2 error: 3.1731430000, Elapsed time: 0:00:00.664682
# Iteration   8, Training L2 error: 0.5259950000, Validation L2 error: 1.3605150000, Elapsed time: 0:00:00.762454
# Iteration  16, Training L2 error: 0.5259950000, Validation L2 error: 1.3605150000, Elapsed time: 0:00:00.827932
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.3588490000
# Training finished. Elapsed time: 0:00:14.100850
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.6572720000, Validation L2 error: 7.9296050000, Elapsed time: 0:00:00.796434
# Iteration   8, Training L2 error: 0.4558840000, Validation L2 error: 1.9547690000, Elapsed time: 0:00:00.824645
# Iteration  16, Training L2 error: 0.4558840000, Validation L2 error: 1.9547690000, Elapsed time: 0:00:00.849108
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 1.9547420000
# Training finished. Elapsed time: 0:00:16.226085
#
# Participant: participant_96, got a new best CV score: 1.589537419046665 with params: {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
#
# Testing CV with params: {'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 0.5, 'min_split_gain': 0.1}
# 5-Fold CV for participant: participant_116
# Training until validation scores don't improve for 16 rounds.
# Iteration   1, Training's L2 error: 0.2066360000
# Training finished. Elapsed time: 0:00:02.994642
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.5311940000, Validation L2 error: 0.5841350000, Elapsed time: 0:00:00.148788
# Iteration   8, Training L2 error: 0.1257650000, Validation L2 error: 0.2693400000, Elapsed time: 0:00:00.156216
# Iteration  16, Training L2 error: 0.1257650000, Validation L2 error: 0.2693400000, Elapsed time: 0:00:00.183920
# Early stopping. Best iteration is:
# Iteration   5, Training's L2 error: 0.2693400000
# Training finished. Elapsed time: 0:00:03.746976
#
# Participant: participant_176, got a new best CV score: 0.6480063179353223 with params: {'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 0.5, 'min_split_gain': 0.1}
#
# 5-Fold CV for participant: participant_21
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 1.1564490000, Validation L2 error: 0.9079800000, Elapsed time: 0:00:00.161689
# Iteration   8, Training L2 error: 0.1120220000, Validation L2 error: 0.1494530000, Elapsed time: 0:00:00.172198
# Iteration  16, Training L2 error: 0.1120220000, Validation L2 error: 0.1494530000, Elapsed time: 0:00:00.238363
# Early stopping. Best iteration is:
# Iteration   7, Training's L2 error: 0.1494530000
# Training finished. Elapsed time: 0:00:04.445361
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.8798720000, Validation L2 error: 0.9276070000, Elapsed time: 0:00:00.140588
# Iteration   8, Training L2 error: 0.0422260000, Validation L2 error: 0.2073170000, Elapsed time: 0:00:00.171834
# Iteration  16, Training L2 error: 0.0422260000, Validation L2 error: 0.2073170000, Elapsed time: 0:00:00.187456
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.2071540000
# Training finished. Elapsed time: 0:00:03.224772
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.9114450000, Validation L2 error: 1.3883490000, Elapsed time: 0:00:00.171890
# Iteration   8, Training L2 error: 0.0962300000, Validation L2 error: 0.1157840000, Elapsed time: 0:00:00.171830
# Iteration  16, Training L2 error: 0.0962300000, Validation L2 error: 0.1157840000, Elapsed time: 0:00:00.171826
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 0.1157220000
# Training finished. Elapsed time: 0:00:03.404158
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.8809010000, Validation L2 error: 0.6947630000, Elapsed time: 0:00:00.156233
# Iteration   8, Training L2 error: 0.0605040000, Validation L2 error: 0.2788820000, Elapsed time: 0:00:00.156211
# ...
# Iteration  16, Training L2 error: 0.0677150000, Validation L2 error: 0.0443680000, Elapsed time: 0:00:00.156215
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 0.0443670000
# Training finished. Elapsed time: 0:00:02.768641
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 0.8054910000, Validation L2 error: 0.7061920000, Elapsed time: 0:00:00.114188
# Iteration   8, Training L2 error: 0.0182870000, Validation L2 error: 0.2631650000, Elapsed time: 0:00:00.093725
# Iteration  16, Training L2 error: 0.5842010000, Validation L2 error: 3.0677680000, Elapsed time: 0:00:00.827909
# Early stopping. Best iteration is:
# Iteration   2, Training's L2 error: 3.0677640000
# Training finished. Elapsed time: 0:00:15.335261
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 6.6438530000, Validation L2 error: 1.5253430000, Elapsed time: 0:00:00.696478
# Iteration   8, Training L2 error: 0.5674750000, Validation L2 error: 1.2821010000, Elapsed time: 0:00:00.783831
# Iteration  16, Training L2 error: 0.5674750000, Validation L2 error: 1.2821010000, Elapsed time: 0:00:00.845247
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.2816800000
# Training finished. Elapsed time: 0:00:14.417181
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 2.7936590000, Validation L2 error: 7.6178150000, Elapsed time: 0:00:00.609168
# Iteration   8, Training L2 error: 0.4300030000, Validation L2 error: 2.6246390000, Elapsed time: 0:00:00.765475
# Iteration  16, Training L2 error: 0.4300030000, Validation L2 error: 2.6246390000, Elapsed time: 0:00:00.844999
# Early stopping. Best iteration is:
# Iteration   4, Training's L2 error: 2.6246390000
# Training finished. Elapsed time: 0:00:16.980545
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 4.8590640000, Validation L2 error: 1.7519640000, Elapsed time: 0:00:00.665713
# Iteration   8, Training L2 error: 0.3835220000, Validation L2 error: 2.3665060000, Elapsed time: 0:00:00.749804
# Iteration  16, Training L2 error: 0.3835220000, Validation L2 error: 2.3665060000, Elapsed time: 0:00:00.827932
# Early stopping. Best iteration is:
# Iteration   3, Training's L2 error: 2.3665060000
# Training finished. Elapsed time: 0:00:15.864454
#
# Training until validation scores don't improve for 16 rounds.
# Iteration   0, Training L2 error: 3.7637140000, Validation L2 error: 4.6504210000, Elapsed time: 0:00:00.660125
# Iteration   8, Training L2 error: 0.4357970000, Validation L2 error: 1.1489680000, Elapsed time: 0:00:00.765444
# Iteration  16, Training L2 error: 0.4357970000, Validation L2 error: 1.1489680000, Elapsed time: 0:00:00.835319
# Early stopping. Best iteration is:
# Iteration   1, Training's L2 error: 1.1483980000
# Training finished. Elapsed time: 0:00:14.334538
#
# CV finished. Elapsed time: 0:21:48.983124

# %% [markdown]
# ##### V-Fold Cross Validation results
#
# The list of the best  per-participant parameters for each CART model is available below, together with its corresponding RMSE.

# %%
global_rmse = 0
for participant, CV_info in best_CV_info_GBM.items():
    global_rmse += CV_info.score
    print(participant.capitalize(), CV_info.score, CV_info.params)
    
print('Global RMSE: {:3f}'.format(global_rmse/len(best_CV_info_GBM.items())))
# Out:
# Participant_116 0.9119216628586337 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_120 0.7697847348235587 {'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 0.5, 'min_split_gain': 0.1}
# Participant_146 1.3088900572624356 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_158 1.3151635550753067 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.3}
# Participant_176 0.8052881250788282 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.3}
# Participant_21 0.7105163300850751 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_60 1.314916729181168 {'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 0.5, 'min_split_gain': 0.1}
# Participant_75 1.4595825910004208 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_87 2.740908939107856 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_89 1.3623949895175045 {'gamma': 0.3, 'lambda': 1.0, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.33, 'min_split_gain': 0.5}
# Participant_96 2.0261415571209636 {'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 0.5, 'min_split_gain': 0.1}
# Global RMSE: 1.338683

# %% [markdown]
# After the extraction of the best per-participant parameters from the parallel V-Fold CV, the validation scores saw a really big improvement, aside from Participant_87 and Participant_96 that still had a *RMSE* >= 1. For the former, the problem may lie in the 2 non-uniform technologies that he has, since they range from 0-1 n_acc_offers in the first one, to 5-6 in the second one. For the latter, instead, the problem may lie on him being tied at the top of who has the most technologies, 5. With these many time series, an approach more focused on the individual technologies may have been more suitable.

# %%
# # Uncomment the following lines to override the per-participant
# # CART models generated in the previous blocks

with open('best_CV_info_GBM.pickle', 'wb') as f:
    pickle.dump(best_CV_info_GBM, f)

# %% [markdown]
# ##### Testing IREN data
#
# A prediction of the fresh test set is computed, using the best models for each participant.

# %%
import gc

# Load CSV test XY
test_X_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_X.csv', index_col='date', header=0, sep=';')
test_Y_df = pd.read_csv('./preprocessing/generated_csv/IREN_test_Y.csv', index_col='date', header=0, sep=';')

# Encode technologies according to the previously
# saved encoding scheme enc_technologies
test_X_df.technology = enc_technologies.transform(test_X_df.technology)

# Normalize the DF on the following multi-indexes to
# extract the target n_acc_offers in a fixed order
test_Y_target_GBM = test_Y_df.pivot_table(index='date',
                            columns=['participant', 'technology']) \
                    .swaplevel(axis=1).sort_index(1).to_numpy().ravel('K')

# Columns dropped from the test set input X
out_features=['date', 'participant']

# Number of folds used in V-Fold CV
num_folds = 5

# Init the Y predictions array
test_Y_pred_GBM = []

for participant in best_CV_info_GBM.keys():
    print("Extracting {}'s data...".format(participant.capitalize()))

    ## Divide and Conquer strategy
    
    # Extract the participant XY
    X_test_Participant = test_X_df.loc[test_X_df.participant
                                == participant].reset_index()
    
    # Collect dates in X
    X_test_Participant_date = X_test_Participant.date

    # Drop undesired columns
    X_test_Participant.drop(columns=out_features, inplace=True)
    
    # Init the per-participant Y predictions array
    Y_pred_test_Participant = np.zeros(X_test_Participant.shape[0])
    
    test_single_Y_df = None
  
    # Loop for each per-participant model
    for fold_idx in range(num_folds):
        # Extract the current model
        model_GBDT = best_CV_info_GBM[participant].models[fold_idx]
        
        # Accumulate the predictions
        Y_pred_test_Participant += model_GBDT.predict(X_test_Participant.to_numpy(),
                num_iterations=model_GBDT.best_iteration) / num_folds
        
        gc.collect()
        
    # Rounding since n_acc_offers are integers in N >= 0
    Y_pred_test_Participant = np.round(Y_pred_test_Participant).astype(int)
    Y_pred_test_Participant[Y_pred_test_Participant < 0] = 0
                            
    # Create the DF entry
    test_single_Y_df = pd.DataFrame({'technology': enc_technologies.inverse_transform(
                                            X_test_Participant.technology),
                            'date': X_test_Participant_date, 'participant': participant,
                            'n_acc_offers': Y_pred_test_Participant})
    
    test_Y_pred_GBM.append(test_single_Y_df)
    
    print("{} scoring is completed\n".format(participant.capitalize()))
    gc.collect()
        
test_Y_pred_GBM_df = pd.concat(test_Y_pred_GBM)

# Normalize the DF on the same multi-indexes I
# used to extract the target n_acc_offers from test_Y_df
test_Y_pred_target_GBM = test_Y_pred_GBM_df.pivot_table(index='date',
                                        columns=['participant', 'technology']) \
                                .swaplevel(axis=1).sort_index(1).to_numpy().ravel('K')
# Out:
# Extracting Participant_116's data...
# Participant_116 scoring is completed
#
# Extracting Participant_120's data...
# Participant_120 scoring is completed
#
# Extracting Participant_146's data...
# Participant_146 scoring is completed
#
# Extracting Participant_158's data...
# Participant_158 scoring is completed
#
# Extracting Participant_176's data...
# Participant_176 scoring is completed
#
# Extracting Participant_21's data...
# Participant_21 scoring is completed
#
# Extracting Participant_60's data...
# Participant_60 scoring is completed
#
# Extracting Participant_75's data...
# Participant_75 scoring is completed
#
# Extracting Participant_87's data...
# Participant_87 scoring is completed
#
# Extracting Participant_89's data...
# Participant_89 scoring is completed
#
# Extracting Participant_96's data...
# Participant_96 scoring is completed

# %% [markdown]
# ##### Performance and plots
#
# Global RMSE error below:

# %%
print('Test RMSE error with GBDT: {}'.format(np.sqrt(calculate_MSE(
                test_Y_target_GBM, test_Y_pred_target_GBM))))
# Out:
# Test RMSE error with GBDT: 1.0151907431108496

# %% [markdown]
# ##### Thoughts on test
#
# Unfortunately the GBM model showed to be really struggling at predicting the target n_acc_offers when the offers where above 3. It also may have overfitted the data, since many of the predictions were flat. So probably upping `early_boosting_rounds` may be a good choice, if it could run a little faster. Honestly, it was quite surprising given the amount of combinations (almost 500) tried during the V-Fold CV and that it actually responded pretty well on the sample data that was hosted at [Light GBM's GitHub](https://github.com/Microsoft/LightGBM/tree/master/examples/regression]) with a test RMSE of 0.45875 against LightGBM's 0.45652.

# %% [markdown]
# The RMSE for each (`participant`,`technology`) is computed and shown.<br>
# The plots of all the forecasted time series are provided vs the ground truth in test_Y_df

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams.update({'figure.max_open_warning': 50})

for i, pair in enumerate(unique_pairs):
    
    current_true_Y_df = test_Y_df.n_acc_offers[(test_Y_df['participant'] == pair[0]) \
                                & (test_Y_df['technology'] == pair[1])]
    current_pred_Y_df = test_Y_pred_GBM_df.n_acc_offers[(test_Y_pred_GBM_df['participant'] == pair[0]) \
                                & (test_Y_pred_GBM_df['technology'] == pair[1])]
    
    true_Y = current_true_Y_df.to_numpy()
    pred_Y = current_pred_Y_df.to_numpy()
    
    current_MSE = np.sqrt(calculate_MSE(true_Y, pred_Y))
    
    print(pair[0].capitalize(), pair[1], current_MSE)
    
    plt.figure(i,figsize=(16,5))
    
    plt.title('{} {}: RMSE {:5f}'.format(pair[0].capitalize(), pair[1], current_MSE))
    
    plt.plot(current_true_Y_df.index, true_Y, label='True target', ls=':')
    plt.plot(current_true_Y_df.index, pred_Y, label='Prediction')
        
    plt.legend()
# Out:
# Participant_116 ccgt 0.0
# Participant_116 ccgt400 0.7559289460184544
# Participant_116 ccgt800 0.6546536707079771
# Participant_116 pump 0.0
# Participant_116 reservoir 0.9258200997725514
# Participant_120 ccgt800 0.0
# Participant_146 pump 0.8451542547285166
# Participant_146 reservoir 0.0
# Participant_158 ccgt400 0.9258200997725514
# Participant_158 ccgt800 0.9258200997725514
# Participant_158 pump 1.1338934190276817
# Participant_158 reservoir 0.7559289460184544
# Participant_176 ccgt800 0.0
# Participant_21 reservoir 1.0
# Participant_60 ccgt400 1.0
# Participant_75 ccgt400 1.558387444947959
# Participant_75 ccgt800 1.7728105208558367
# Participant_87 ccgt 0.9258200997725514
# Participant_87 ccgt400 2.32992949004287
# Participant_89 ccgt400 0.3779644730092272
# Participant_89 ccgt800 1.0690449676496976
# Participant_89 coal 1.0
# Participant_89 reservoir 1.0
# Participant_96 ccgt400 0.6546536707079771
# Participant_96 ccgt800 0.0
# Participant_96 coal 1.1952286093343936
# Participant_96 pump 1.4638501094227998
# Participant_96 reservoir 1.2535663410560174

# %% [markdown]
# #### LightGBM comparisons
#
# At C1A0 Hackathon we actually used Microsoft's recent LightGBM library, which proved to have amazing speed and accuracy if compared with all the other popular choices. Here below we provide a brief analysis on V-Fold CV and test performance of LightGBM itself.

# %%
from tqdm.notebook import tqdm
from sklearn.model_selection import KFold

import lightgbm as lgb
import gc

# %%
# Uncomment to skip CV
# import pickle

# with open('./best_CV_infos_LGBM.pickle', 'rb') as f:
#     best_CV_infos_LGBM = pickle.load(f)

# %%
def launch_IREN_VFoldCV_lightGBM(training_df, params_combinats,
                            participants, seed=32, num_folds=5,
                            cat_features=['technology'],
                            out_features=['n_acc_offers', 'participant']):
    """V-Fold CV tuned for IREN case study"""
    
    from datetime import datetime
    CV_start_time = datetime.now()
    
    # Output CV info per participant 
    best_CV_infos_LGBM = {}

    for participant in participants:
        best_CV_infos_LGBM[participant] = CVInfo()
        
    for params in params_combinats:
        print('Testing CV with params:', params)
        current_GBDT_models = {}

        for participant in participants:
            print("{}-Fold CV for participant:".format(num_folds), participant)

            KF_generator = KFold(n_splits=num_folds, random_state=seed)
            current_GBDT_models[participant] = []

            # Separate current XY sets
            X_train_Participant = training_df.loc[training_df.participant
                                        == participant].reset_index(drop=True)

            Y_train_Participant = X_train_Participant.n_acc_offers
            X_train_Participant.drop(columns=out_features, inplace=True)

            CV_score = 0

            # Fit the CART learners on each fold
            for fold_idx, (train_idx, valid_idx) in enumerate(
                                KF_generator.split(X_train_Participant, Y_train_Participant)):

                X_train, X_valid = X_train_Participant.loc[train_idx], \
                        X_train_Participant.loc[valid_idx]

                Y_train, Y_valid = Y_train_Participant.iloc[train_idx], \
                        Y_train_Participant.iloc[valid_idx]
                
                D_train = lgb.Dataset(X_train, label=Y_train, categorical_feature=cat_features)
                D_valid = lgb.Dataset(X_valid, label=Y_valid, categorical_feature=cat_features)

                watchlist = [D_train, D_valid]
                
                model_LGBM = lgb.train(params, train_set=D_train, num_boost_round=3000, 
                              valid_sets=watchlist, verbose_eval=101, early_stopping_rounds=125)
        
                current_GBDT_models[participant].append(model_LGBM)

                Y_pred_valid = model_LGBM.predict(X_valid,
                                    num_iteration=model_LGBM.best_iteration)

                validation_RMSE = np.sqrt(calculate_MSE(Y_valid, Y_pred_valid))       
                CV_score += validation_RMSE / num_folds
                print("{} at fold_idx {} with RMSE: {}\n" \
                            .format(participant.capitalize(), fold_idx, validation_RMSE))
                
                gc.collect()

            if best_CV_infos_LGBM[participant].check_score(CV_score,
                        current_GBDT_models[participant], params):
                print('{} got a new best CV score: {} with params: {}\n' \
                            .format(participant.capitalize(), CV_score, params))
    
    print('CV finished. Elapsed time: {}' \
                .format(datetime.now() - CV_start_time))
            
    return best_CV_infos_LGBM

# %%
# Parameters used at C1A0 Hackhaton
params_combinats = [
    {
        "objective": "regression",
        "num_leaves": 50,
        "learning_rate": 0.3,
        "bagging_fraction": 0.90,
        "feature_fraction": 0.87,
        "metric": "rmse"
    },
    {
        "objective": "regression",
        "num_leaves": 50,
        "learning_rate": 0.1,
        "bagging_fraction": 0.90,
        "feature_fraction": 0.75,
        "metric": "rmse"
    },
    {
        "objective": "regression",
        "num_leaves": 35,
        "learning_rate": 0.05,
        "bagging_fraction": 0.90,
        "feature_fraction": 0.75,
        "metric": "rmse"
    }
]

# %% [markdown]
# ##### Launch V-Fold CV

# %%
best_CV_infos_LGBM = launch_IREN_VFoldCV_lightGBM(training_df, params_combinats,
                            u_participants, num_folds=5)
# Out:
# Testing CV with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
# 5-Fold CV for participant: participant_116
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0303499	valid_1's rmse: 1.12681
# Early stopping, best iteration is:
# [6]	training's rmse: 0.208101	valid_1's rmse: 0.967838
# Participant_116 at fold_idx 0 with RMSE: 0.9678381265260487
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.028562	valid_1's rmse: 0.435972
# Early stopping, best iteration is:
# [8]	training's rmse: 0.169932	valid_1's rmse: 0.389224
# Participant_116 at fold_idx 1 with RMSE: 0.7443150208898344
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0272207	valid_1's rmse: 0.542783
# Early stopping, best iteration is:
# [1]	training's rmse: 0.576599	valid_1's rmse: 0.383504
# Participant_116 at fold_idx 2 with RMSE: 0.38350429502665856
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.032828	valid_1's rmse: 0.447723
# Early stopping, best iteration is:
# [1]	training's rmse: 0.586878	valid_1's rmse: 0.264612
# Participant_116 at fold_idx 3 with RMSE: 0.26461244139946966
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0271718	valid_1's rmse: 0.457911
# Early stopping, best iteration is:
# [6]	training's rmse: 0.183655	valid_1's rmse: 0.437349
# Participant_116 at fold_idx 4 with RMSE: 0.4373494324048403
#
# Participant_116 got a new best CV score: 0.5595238632493703 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_120
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0261035	valid_1's rmse: 0.380296
# Early stopping, best iteration is:
# [4]	training's rmse: 0.313468	valid_1's rmse: 0.285999
# Participant_120 at fold_idx 0 with RMSE: 0.2859993833905633
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.01756	valid_1's rmse: 0.557005
# Early stopping, best iteration is:
# [1]	training's rmse: 0.379709	valid_1's rmse: 0.471904
# Participant_120 at fold_idx 1 with RMSE: 0.47190358059868437
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.041879	valid_1's rmse: 0.490296
# Early stopping, best iteration is:
# [15]	training's rmse: 0.174145	valid_1's rmse: 0.474411
# Participant_120 at fold_idx 2 with RMSE: 0.47441102226438536
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0283355	valid_1's rmse: 0.665698
# Early stopping, best iteration is:
# [1]	training's rmse: 0.402455	valid_1's rmse: 0.500676
# Participant_120 at fold_idx 3 with RMSE: 0.5006764811057313
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0247815	valid_1's rmse: 0.432226
# Early stopping, best iteration is:
# [2]	training's rmse: 0.359008	valid_1's rmse: 0.364942
# Participant_120 at fold_idx 4 with RMSE: 0.36494242669749194
#
# Participant_120 got a new best CV score: 0.4195865788113713 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_146
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0686095	valid_1's rmse: 0.696298
# Early stopping, best iteration is:
# [13]	training's rmse: 0.305605	valid_1's rmse: 0.627332
# Participant_146 at fold_idx 0 with RMSE: 0.6273319496169774
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0754554	valid_1's rmse: 0.655499
# Early stopping, best iteration is:
# [1]	training's rmse: 0.649177	valid_1's rmse: 0.46091
# Participant_146 at fold_idx 1 with RMSE: 0.46090977131047334
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.069741	valid_1's rmse: 0.825123
# Early stopping, best iteration is:
# [2]	training's rmse: 0.542817	valid_1's rmse: 0.677419
# Participant_146 at fold_idx 2 with RMSE: 0.6774186945770122
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0728835	valid_1's rmse: 0.628459
# Early stopping, best iteration is:
# [11]	training's rmse: 0.336935	valid_1's rmse: 0.580228
# Participant_146 at fold_idx 3 with RMSE: 0.5802282063852766
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0663016	valid_1's rmse: 0.914426
# Early stopping, best iteration is:
# [11]	training's rmse: 0.329231	valid_1's rmse: 0.776454
# Participant_146 at fold_idx 4 with RMSE: 0.7764538484047785
#
# Participant_146 got a new best CV score: 0.6244684940589036 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_158
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.045353	valid_1's rmse: 0.733353
# Early stopping, best iteration is:
# [3]	training's rmse: 0.450026	valid_1's rmse: 0.587172
# Participant_158 at fold_idx 0 with RMSE: 0.5871716122461331
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0474367	valid_1's rmse: 0.517962
# Early stopping, best iteration is:
# [10]	training's rmse: 0.271296	valid_1's rmse: 0.439048
# Participant_158 at fold_idx 1 with RMSE: 0.4390483221511366
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0442854	valid_1's rmse: 0.498365
# Early stopping, best iteration is:
# [14]	training's rmse: 0.216784	valid_1's rmse: 0.472589
# Participant_158 at fold_idx 2 with RMSE: 0.47258879774060547
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0411128	valid_1's rmse: 0.67589
# Early stopping, best iteration is:
# [4]	training's rmse: 0.393393	valid_1's rmse: 0.618479
# Participant_158 at fold_idx 3 with RMSE: 0.6184793172526346
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0447112	valid_1's rmse: 0.522167
# Early stopping, best iteration is:
# [11]	training's rmse: 0.252487	valid_1's rmse: 0.51586
# Participant_158 at fold_idx 4 with RMSE: 0.5158600983088082
#
# Participant_158 got a new best CV score: 0.5266296295398636 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_176
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0246168	valid_1's rmse: 0.614633
# Early stopping, best iteration is:
# [1]	training's rmse: 0.402112	valid_1's rmse: 0.484719
# Participant_176 at fold_idx 0 with RMSE: 0.48471867083366216
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0253961	valid_1's rmse: 0.699104
# Early stopping, best iteration is:
# [1]	training's rmse: 0.3843	valid_1's rmse: 0.61431
# Participant_176 at fold_idx 1 with RMSE: 0.6143104328784665
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0264431	valid_1's rmse: 0.434428
# Early stopping, best iteration is:
# [1]	training's rmse: 0.427487	valid_1's rmse: 0.367254
# Participant_176 at fold_idx 2 with RMSE: 0.3672544364217853
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0224224	valid_1's rmse: 0.415662
# Early stopping, best iteration is:
# [10]	training's rmse: 0.205649	valid_1's rmse: 0.396109
# Participant_176 at fold_idx 3 with RMSE: 0.39610925025181537
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0258831	valid_1's rmse: 0.514983
# Early stopping, best iteration is:
# [6]	training's rmse: 0.267971	valid_1's rmse: 0.393103
# Participant_176 at fold_idx 4 with RMSE: 0.3931033504664156
#
# Participant_176 got a new best CV score: 0.451099228170429 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_21
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0193012	valid_1's rmse: 0.23104
# Early stopping, best iteration is:
# [1]	training's rmse: 0.32508	valid_1's rmse: 0.209159
# Participant_21 at fold_idx 0 with RMSE: 0.2091590557752162
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0160687	valid_1's rmse: 0.50654
# Early stopping, best iteration is:
# [3]	training's rmse: 0.235583	valid_1's rmse: 0.444047
# Participant_21 at fold_idx 1 with RMSE: 0.4440472900974211
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.027439	valid_1's rmse: 0.419253
# Early stopping, best iteration is:
# [1]	training's rmse: 0.321945	valid_1's rmse: 0.21252
# Participant_21 at fold_idx 2 with RMSE: 0.21252022136206172
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0238991	valid_1's rmse: 0.518711
# Early stopping, best iteration is:
# [3]	training's rmse: 0.216435	valid_1's rmse: 0.496129
# Participant_21 at fold_idx 3 with RMSE: 0.49612938695328757
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0253734	valid_1's rmse: 0.330894
# Early stopping, best iteration is:
# [1]	training's rmse: 0.317202	valid_1's rmse: 0.248806
# Participant_21 at fold_idx 4 with RMSE: 0.24880564516505463
#
# Participant_21 got a new best CV score: 0.32213231987060825 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_60
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0417728	valid_1's rmse: 0.48373
# Early stopping, best iteration is:
# [4]	training's rmse: 0.266996	valid_1's rmse: 0.207275
# Participant_60 at fold_idx 0 with RMSE: 0.2072749448890769
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0395845	valid_1's rmse: 0.495517
# Early stopping, best iteration is:
# [73]	training's rmse: 0.0534578	valid_1's rmse: 0.49196
# Participant_60 at fold_idx 1 with RMSE: 0.491960255589281
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0303219	valid_1's rmse: 0.31895
# [202]	training's rmse: 0.00848769	valid_1's rmse: 0.320341
# Early stopping, best iteration is:
# [97]	training's rmse: 0.0320528	valid_1's rmse: 0.318449
# Participant_60 at fold_idx 2 with RMSE: 0.31844936916186195
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0269034	valid_1's rmse: 0.338562
# Early stopping, best iteration is:
# [2]	training's rmse: 0.300027	valid_1's rmse: 0.225309
# Participant_60 at fold_idx 3 with RMSE: 0.22530914702322077
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0261145	valid_1's rmse: 0.352142
# Early stopping, best iteration is:
# [1]	training's rmse: 0.303536	valid_1's rmse: 0.296051
# Participant_60 at fold_idx 4 with RMSE: 0.29605072858274606
#
# Participant_60 got a new best CV score: 0.3078088890492373 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_75
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.053556	valid_1's rmse: 0.817818
# Early stopping, best iteration is:
# [9]	training's rmse: 0.344256	valid_1's rmse: 0.760959
# Participant_75 at fold_idx 0 with RMSE: 0.7609585700599868
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0516016	valid_1's rmse: 0.826137
# Early stopping, best iteration is:
# [6]	training's rmse: 0.39901	valid_1's rmse: 0.754048
# Participant_75 at fold_idx 1 with RMSE: 0.7540476797888174
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0558065	valid_1's rmse: 0.743365
# Early stopping, best iteration is:
# [15]	training's rmse: 0.267726	valid_1's rmse: 0.684427
# Participant_75 at fold_idx 2 with RMSE: 0.684426884644426
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0505279	valid_1's rmse: 0.705739
# Early stopping, best iteration is:
# [6]	training's rmse: 0.401404	valid_1's rmse: 0.676279
# Participant_75 at fold_idx 3 with RMSE: 0.676279376296173
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0536194	valid_1's rmse: 0.67761
# Early stopping, best iteration is:
# [8]	training's rmse: 0.37536	valid_1's rmse: 0.634633
# Participant_75 at fold_idx 4 with RMSE: 0.6346332761759493
#
# Participant_75 got a new best CV score: 0.7020691573930705 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_87
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0467085	valid_1's rmse: 0.874149
# Early stopping, best iteration is:
# [14]	training's rmse: 0.239435	valid_1's rmse: 0.762044
# Participant_87 at fold_idx 0 with RMSE: 0.7620439840914812
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0521326	valid_1's rmse: 0.557353
# Early stopping, best iteration is:
# [16]	training's rmse: 0.224838	valid_1's rmse: 0.494703
# Participant_87 at fold_idx 1 with RMSE: 0.49470304375816115
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0489429	valid_1's rmse: 0.732033
# Early stopping, best iteration is:
# [15]	training's rmse: 0.228632	valid_1's rmse: 0.66665
# Participant_87 at fold_idx 2 with RMSE: 0.6666500714307452
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0458044	valid_1's rmse: 0.646681
# [202]	training's rmse: 0.0162792	valid_1's rmse: 0.636368
# [303]	training's rmse: 0.00801876	valid_1's rmse: 0.635907
# [404]	training's rmse: 0.00446634	valid_1's rmse: 0.635322
# [505]	training's rmse: 0.00262509	valid_1's rmse: 0.634916
# [606]	training's rmse: 0.00145334	valid_1's rmse: 0.635512
# Early stopping, best iteration is:
# [486]	training's rmse: 0.00295707	valid_1's rmse: 0.634689
# Participant_87 at fold_idx 3 with RMSE: 0.6346889370665798
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0239967	valid_1's rmse: 1.17417
# Early stopping, best iteration is:
# [4]	training's rmse: 0.697148	valid_1's rmse: 0.906592
# Participant_87 at fold_idx 4 with RMSE: 0.9065918997741317
#
# Participant_87 got a new best CV score: 0.6929355872242198 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_89
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0516869	valid_1's rmse: 0.790095
# Early stopping, best iteration is:
# [14]	training's rmse: 0.271754	valid_1's rmse: 0.737507
# Participant_89 at fold_idx 0 with RMSE: 0.737506818854636
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0497977	valid_1's rmse: 0.870382
# Early stopping, best iteration is:
# [20]	training's rmse: 0.199312	valid_1's rmse: 0.854852
# Participant_89 at fold_idx 1 with RMSE: 0.8548522984726296
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0514351	valid_1's rmse: 0.777685
# Early stopping, best iteration is:
# [8]	training's rmse: 0.363723	valid_1's rmse: 0.709352
# Participant_89 at fold_idx 2 with RMSE: 0.7093521151600104
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0561182	valid_1's rmse: 0.571101
# Early stopping, best iteration is:
# [4]	training's rmse: 0.531889	valid_1's rmse: 0.468056
# Participant_89 at fold_idx 3 with RMSE: 0.46805569270961567
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0578942	valid_1's rmse: 0.357371
# Early stopping, best iteration is:
# [10]	training's rmse: 0.366328	valid_1's rmse: 0.288425
# Participant_89 at fold_idx 4 with RMSE: 0.28842458278209904
#
# Participant_89 got a new best CV score: 0.6116383015957981 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_96
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0781794	valid_1's rmse: 0.989512
# Early stopping, best iteration is:
# [5]	training's rmse: 0.576663	valid_1's rmse: 0.920747
# Participant_96 at fold_idx 0 with RMSE: 0.9359440288603291
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0969929	valid_1's rmse: 1.5773
# Early stopping, best iteration is:
# [14]	training's rmse: 0.432688	valid_1's rmse: 1.39011
# Participant_96 at fold_idx 1 with RMSE: 1.2842991387742884
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0740701	valid_1's rmse: 1.51994
# Early stopping, best iteration is:
# [16]	training's rmse: 0.306368	valid_1's rmse: 1.47075
# Participant_96 at fold_idx 2 with RMSE: 1.5216612568962826
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0775331	valid_1's rmse: 1.06473
# Early stopping, best iteration is:
# [5]	training's rmse: 0.579536	valid_1's rmse: 0.991955
# Participant_96 at fold_idx 3 with RMSE: 0.9914538734285242
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0790428	valid_1's rmse: 1.00268
# Early stopping, best iteration is:
# [5]	training's rmse: 0.619909	valid_1's rmse: 0.741388
# Participant_96 at fold_idx 4 with RMSE: 0.7441660878912424
#
# Participant_96 got a new best CV score: 1.0955048771701332 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.3, 'bagging_fraction': 0.9, 'feature_fraction': 0.87, 'metric': 'rmse'}
#
# Testing CV with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
# 5-Fold CV for participant: participant_116
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0911712	valid_1's rmse: 1.18274
# Early stopping, best iteration is:
# [39]	training's rmse: 0.158031	valid_1's rmse: 1.15486
# Participant_116 at fold_idx 0 with RMSE: 1.0574139295688032
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0824479	valid_1's rmse: 0.434238
# Early stopping, best iteration is:
# [24]	training's rmse: 0.171947	valid_1's rmse: 0.406254
# Participant_116 at fold_idx 1 with RMSE: 0.776053954940116
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0867493	valid_1's rmse: 0.566485
# Early stopping, best iteration is:
# [1]	training's rmse: 0.718667	valid_1's rmse: 0.34064
# Participant_116 at fold_idx 2 with RMSE: 0.34063994227469635
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0957913	valid_1's rmse: 0.440388
# Early stopping, best iteration is:
# [1]	training's rmse: 0.728752	valid_1's rmse: 0.209644
# Participant_116 at fold_idx 3 with RMSE: 0.20964383428717498
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0694054	valid_1's rmse: 0.483503
# Early stopping, best iteration is:
# [53]	training's rmse: 0.103551	valid_1's rmse: 0.477955
# Participant_116 at fold_idx 4 with RMSE: 0.47930805788990255
#
# Participant_116 got a new best CV score: 0.5726119437921386 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_120
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.109168	valid_1's rmse: 0.364586
# Early stopping, best iteration is:
# [10]	training's rmse: 0.334713	valid_1's rmse: 0.285952
# Participant_120 at fold_idx 0 with RMSE: 0.28595169233909773
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.079506	valid_1's rmse: 0.55665
# Early stopping, best iteration is:
# [6]	training's rmse: 0.336075	valid_1's rmse: 0.463239
# Participant_120 at fold_idx 1 with RMSE: 0.46323852349167927
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.103959	valid_1's rmse: 0.498731
# Early stopping, best iteration is:
# [33]	training's rmse: 0.199792	valid_1's rmse: 0.470336
# Participant_120 at fold_idx 2 with RMSE: 0.47033580256434865
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.100049	valid_1's rmse: 0.584847
# Early stopping, best iteration is:
# [3]	training's rmse: 0.407874	valid_1's rmse: 0.488907
# Participant_120 at fold_idx 3 with RMSE: 0.4889066117519792
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.106826	valid_1's rmse: 0.417253
# Early stopping, best iteration is:
# [11]	training's rmse: 0.314285	valid_1's rmse: 0.360968
# Participant_120 at fold_idx 4 with RMSE: 0.36096767310099054
#
# 5-Fold CV for participant: participant_146
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.195663	valid_1's rmse: 0.657825
# Early stopping, best iteration is:
# [33]	training's rmse: 0.332089	valid_1's rmse: 0.632023
# Participant_146 at fold_idx 0 with RMSE: 0.6320225864582006
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.211027	valid_1's rmse: 0.635173
# Early stopping, best iteration is:
# [4]	training's rmse: 0.62503	valid_1's rmse: 0.463266
# Participant_146 at fold_idx 1 with RMSE: 0.46326626987328295
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.185994	valid_1's rmse: 0.746172
# Early stopping, best iteration is:
# [6]	training's rmse: 0.547089	valid_1's rmse: 0.676444
# Participant_146 at fold_idx 2 with RMSE: 0.6764436550937617
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.206961	valid_1's rmse: 0.612437
# Early stopping, best iteration is:
# [30]	training's rmse: 0.349471	valid_1's rmse: 0.589141
# Participant_146 at fold_idx 3 with RMSE: 0.5891411049319089
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.19243	valid_1's rmse: 0.854773
# Early stopping, best iteration is:
# [19]	training's rmse: 0.394867	valid_1's rmse: 0.774817
# Participant_146 at fold_idx 4 with RMSE: 0.7748166361733437
#
# Participant_146 got a new best CV score: 0.6271380505060996 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_158
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.12844	valid_1's rmse: 0.692962
# Early stopping, best iteration is:
# [15]	training's rmse: 0.364831	valid_1's rmse: 0.553107
# Participant_158 at fold_idx 0 with RMSE: 0.553106717827041
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.139332	valid_1's rmse: 0.460386
# Early stopping, best iteration is:
# [44]	training's rmse: 0.223191	valid_1's rmse: 0.432436
# Participant_158 at fold_idx 1 with RMSE: 0.43243587403747336
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.128578	valid_1's rmse: 0.469193
# Early stopping, best iteration is:
# [62]	training's rmse: 0.174581	valid_1's rmse: 0.465701
# Participant_158 at fold_idx 2 with RMSE: 0.4657013520703954
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.120347	valid_1's rmse: 0.636212
# Early stopping, best iteration is:
# [12]	training's rmse: 0.436622	valid_1's rmse: 0.593709
# Participant_158 at fold_idx 3 with RMSE: 0.5937091761576624
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.134923	valid_1's rmse: 0.551851
# Early stopping, best iteration is:
# [12]	training's rmse: 0.465484	valid_1's rmse: 0.538549
# Participant_158 at fold_idx 4 with RMSE: 0.5385491213091235
#
# 5-Fold CV for participant: participant_176
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0971153	valid_1's rmse: 0.539106
# Early stopping, best iteration is:
# [3]	training's rmse: 0.408511	valid_1's rmse: 0.457191
# Participant_176 at fold_idx 0 with RMSE: 0.45719057145391234
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.100599	valid_1's rmse: 0.723144
# Early stopping, best iteration is:
# [1]	training's rmse: 0.421075	valid_1's rmse: 0.609445
# Participant_176 at fold_idx 1 with RMSE: 0.6094452538869126
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.106221	valid_1's rmse: 0.391748
# Early stopping, best iteration is:
# [36]	training's rmse: 0.204247	valid_1's rmse: 0.363945
# Participant_176 at fold_idx 2 with RMSE: 0.36394461701448977
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.103506	valid_1's rmse: 0.404734
# Early stopping, best iteration is:
# [23]	training's rmse: 0.247335	valid_1's rmse: 0.394009
# Participant_176 at fold_idx 3 with RMSE: 0.39400904890921945
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.102028	valid_1's rmse: 0.491535
# Early stopping, best iteration is:
# [22]	training's rmse: 0.246576	valid_1's rmse: 0.400699
# Participant_176 at fold_idx 4 with RMSE: 0.400698974808047
#
# 5-Fold CV for participant: participant_21
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0739012	valid_1's rmse: 0.217323
# Early stopping, best iteration is:
# [14]	training's rmse: 0.254341	valid_1's rmse: 0.205167
# Participant_21 at fold_idx 0 with RMSE: 0.2051669288358643
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.065083	valid_1's rmse: 0.486899
# Early stopping, best iteration is:
# [10]	training's rmse: 0.235368	valid_1's rmse: 0.440397
# Participant_21 at fold_idx 1 with RMSE: 0.4403969335120056
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0859449	valid_1's rmse: 0.451123
# Early stopping, best iteration is:
# [1]	training's rmse: 0.351755	valid_1's rmse: 0.172968
# Participant_21 at fold_idx 2 with RMSE: 0.17296788006399974
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0788912	valid_1's rmse: 0.506772
# Early stopping, best iteration is:
# [18]	training's rmse: 0.187459	valid_1's rmse: 0.499427
# Participant_21 at fold_idx 3 with RMSE: 0.49942705464238196
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.084656	valid_1's rmse: 0.303151
# Early stopping, best iteration is:
# [4]	training's rmse: 0.308907	valid_1's rmse: 0.238554
# Participant_21 at fold_idx 4 with RMSE: 0.23855386612786333
#
# 5-Fold CV for participant: participant_60
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.116048	valid_1's rmse: 0.447465
# Early stopping, best iteration is:
# [1]	training's rmse: 0.337958	valid_1's rmse: 0.162836
# Participant_60 at fold_idx 0 with RMSE: 0.1628362728952686
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.095059	valid_1's rmse: 0.497378
# [202]	training's rmse: 0.0603312	valid_1's rmse: 0.493901
# [303]	training's rmse: 0.0430296	valid_1's rmse: 0.490729
# [404]	training's rmse: 0.0333169	valid_1's rmse: 0.489759
# [505]	training's rmse: 0.0261644	valid_1's rmse: 0.489457
# Early stopping, best iteration is:
# [426]	training's rmse: 0.0314329	valid_1's rmse: 0.489186
# Participant_60 at fold_idx 1 with RMSE: 0.4891858970230887
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.106765	valid_1's rmse: 0.330851
# Early stopping, best iteration is:
# [17]	training's rmse: 0.228062	valid_1's rmse: 0.317895
# Participant_60 at fold_idx 2 with RMSE: 0.3178945236011856
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0968181	valid_1's rmse: 0.309462
# Early stopping, best iteration is:
# [1]	training's rmse: 0.330227	valid_1's rmse: 0.207991
# Participant_60 at fold_idx 3 with RMSE: 0.20799054194451208
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0960972	valid_1's rmse: 0.330963
# Early stopping, best iteration is:
# [1]	training's rmse: 0.315435	valid_1's rmse: 0.288212
# Participant_60 at fold_idx 4 with RMSE: 0.2882117473405359
#
# 5-Fold CV for participant: participant_75
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.166242	valid_1's rmse: 0.783385
# Early stopping, best iteration is:
# [30]	training's rmse: 0.330439	valid_1's rmse: 0.752968
# Participant_75 at fold_idx 0 with RMSE: 0.7529676040068213
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.169168	valid_1's rmse: 0.769542
# Early stopping, best iteration is:
# [25]	training's rmse: 0.349952	valid_1's rmse: 0.739625
# Participant_75 at fold_idx 1 with RMSE: 0.7396249241511146
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.165197	valid_1's rmse: 0.691856
# Early stopping, best iteration is:
# [40]	training's rmse: 0.284918	valid_1's rmse: 0.672734
# Participant_75 at fold_idx 2 with RMSE: 0.6727342524511348
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.153667	valid_1's rmse: 0.70892
# Early stopping, best iteration is:
# [18]	training's rmse: 0.412945	valid_1's rmse: 0.645066
# Participant_75 at fold_idx 3 with RMSE: 0.6450661747766736
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.172363	valid_1's rmse: 0.619718
# Early stopping, best iteration is:
# [43]	training's rmse: 0.285017	valid_1's rmse: 0.604047
# Participant_75 at fold_idx 4 with RMSE: 0.6040467669438723
#
# 5-Fold CV for participant: participant_87
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.139038	valid_1's rmse: 0.899206
# Early stopping, best iteration is:
# [53]	training's rmse: 0.209209	valid_1's rmse: 0.889642
# Participant_87 at fold_idx 0 with RMSE: 0.8896422387810665
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.148736	valid_1's rmse: 0.568879
# Early stopping, best iteration is:
# [51]	training's rmse: 0.215438	valid_1's rmse: 0.537029
# Participant_87 at fold_idx 1 with RMSE: 0.5370293244443066
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.142993	valid_1's rmse: 0.75079
# Early stopping, best iteration is:
# [66]	training's rmse: 0.190256	valid_1's rmse: 0.732048
# Participant_87 at fold_idx 2 with RMSE: 0.7320477899199814
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.130794	valid_1's rmse: 0.752801
# [202]	training's rmse: 0.0708755	valid_1's rmse: 0.731969
# [303]	training's rmse: 0.0458345	valid_1's rmse: 0.718078
# [404]	training's rmse: 0.0310566	valid_1's rmse: 0.711216
# [505]	training's rmse: 0.0233562	valid_1's rmse: 0.71249
# [606]	training's rmse: 0.0180595	valid_1's rmse: 0.709542
# [707]	training's rmse: 0.0143921	valid_1's rmse: 0.712204
# Early stopping, best iteration is:
# [596]	training's rmse: 0.0186125	valid_1's rmse: 0.708841
# Participant_87 at fold_idx 3 with RMSE: 0.708840609215835
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.0921425	valid_1's rmse: 1.07323
# Early stopping, best iteration is:
# [16]	training's rmse: 0.605499	valid_1's rmse: 0.884574
# Participant_87 at fold_idx 4 with RMSE: 0.8845737320662357
#
# Participant_87 got a new best CV score: 0.7504267388854851 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_89
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.145268	valid_1's rmse: 0.768321
# Early stopping, best iteration is:
# [43]	training's rmse: 0.264473	valid_1's rmse: 0.747979
# Participant_89 at fold_idx 0 with RMSE: 0.7479793015789636
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.134783	valid_1's rmse: 0.860109
# Early stopping, best iteration is:
# [41]	training's rmse: 0.24027	valid_1's rmse: 0.853868
# Participant_89 at fold_idx 1 with RMSE: 0.8538683709087098
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.160597	valid_1's rmse: 0.720578
# Early stopping, best iteration is:
# [41]	training's rmse: 0.281163	valid_1's rmse: 0.688174
# Participant_89 at fold_idx 2 with RMSE: 0.6881737461079847
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.172338	valid_1's rmse: 0.585457
# Early stopping, best iteration is:
# [16]	training's rmse: 0.488102	valid_1's rmse: 0.486174
# Participant_89 at fold_idx 3 with RMSE: 0.4861737927814009
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.181417	valid_1's rmse: 0.366925
# Early stopping, best iteration is:
# [37]	training's rmse: 0.336372	valid_1's rmse: 0.346224
# Participant_89 at fold_idx 4 with RMSE: 0.3462241114381299
#
# Participant_89 got a new best CV score: 0.6244838645630377 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_96
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.225695	valid_1's rmse: 0.994103
# Early stopping, best iteration is:
# [8]	training's rmse: 0.929466	valid_1's rmse: 0.905051
# Participant_96 at fold_idx 0 with RMSE: 0.905051208440186
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.272015	valid_1's rmse: 1.45541
# Early stopping, best iteration is:
# [49]	training's rmse: 0.399326	valid_1's rmse: 1.38469
# Participant_96 at fold_idx 1 with RMSE: 1.2553823255875876
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.201827	valid_1's rmse: 1.57658
# Early stopping, best iteration is:
# [45]	training's rmse: 0.306999	valid_1's rmse: 1.53964
# Participant_96 at fold_idx 2 with RMSE: 1.6310739728983643
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.221758	valid_1's rmse: 1.05621
# Early stopping, best iteration is:
# [10]	training's rmse: 0.810446	valid_1's rmse: 1.01324
# Participant_96 at fold_idx 3 with RMSE: 1.0140480835179335
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.226937	valid_1's rmse: 0.953149
# Early stopping, best iteration is:
# [21]	training's rmse: 0.530254	valid_1's rmse: 0.815344
# Participant_96 at fold_idx 4 with RMSE: 0.7839978497496647
#
# Participant_96 got a new best CV score: 1.1179106880387473 with params: {'objective': 'regression', 'num_leaves': 50, 'learning_rate': 0.1, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# Testing CV with params: {'objective': 'regression', 'num_leaves': 35, 'learning_rate': 0.05, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
# 5-Fold CV for participant: participant_116
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.146255	valid_1's rmse: 1.21385
# Early stopping, best iteration is:
# [19]	training's rmse: 0.291755	valid_1's rmse: 1.16957
# Participant_116 at fold_idx 0 with RMSE: 1.1198377200713936
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.126336	valid_1's rmse: 0.404633
# [202]	training's rmse: 0.0944516	valid_1's rmse: 0.421847
# Early stopping, best iteration is:
# [81]	training's rmse: 0.138326	valid_1's rmse: 0.401035
# Participant_116 at fold_idx 1 with RMSE: 0.7410806506014813
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.139756	valid_1's rmse: 0.554159
# Early stopping, best iteration is:
# [1]	training's rmse: 0.754767	valid_1's rmse: 0.330984
# Participant_116 at fold_idx 2 with RMSE: 0.3309842805980182
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.157601	valid_1's rmse: 0.404861
# Early stopping, best iteration is:
# [1]	training's rmse: 0.764878	valid_1's rmse: 0.196947
# Participant_116 at fold_idx 3 with RMSE: 0.19694686854732715
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.110625	valid_1's rmse: 0.471825
# [202]	training's rmse: 0.0801526	valid_1's rmse: 0.476882
# Early stopping, best iteration is:
# [90]	training's rmse: 0.116224	valid_1's rmse: 0.471062
# Participant_116 at fold_idx 4 with RMSE: 0.4752901056488197
#
# Participant_116 got a new best CV score: 0.572827925093408 with params: {'objective': 'regression', 'num_leaves': 35, 'learning_rate': 0.05, 'bagging_fraction': 0.9, 'feature_fraction': 0.75, 'metric': 'rmse'}
#
# 5-Fold CV for participant: participant_120
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.169305	valid_1's rmse: 0.350577
# Early stopping, best iteration is:
# [24]	training's rmse: 0.319481	valid_1's rmse: 0.28807
# Participant_120 at fold_idx 0 with RMSE: 0.2880697285228607
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.14385	valid_1's rmse: 0.522934
# Early stopping, best iteration is:
# [13]	training's rmse: 0.332237	valid_1's rmse: 0.461519
# Participant_120 at fold_idx 1 with RMSE: 0.46151917904110185
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.16587	valid_1's rmse: 0.476073
# Early stopping, best iteration is:
# [64]	training's rmse: 0.204746	valid_1's rmse: 0.466278
# Participant_120 at fold_idx 2 with RMSE: 0.466278295123667
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.172235	valid_1's rmse: 0.589079
# Early stopping, best iteration is:
# [6]	training's rmse: 0.408907	valid_1's rmse: 0.485587
# Participant_120 at fold_idx 3 with RMSE: 0.48558744126588904
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.171672	valid_1's rmse: 0.391545
# Early stopping, best iteration is:
# [24]	training's rmse: 0.307543	valid_1's rmse: 0.358658
# Participant_120 at fold_idx 4 with RMSE: 0.3586579657933732
#
# 5-Fold CV for participant: participant_146
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.272525	valid_1's rmse: 0.639116
# Early stopping, best iteration is:
# [62]	training's rmse: 0.338403	valid_1's rmse: 0.622915
# Participant_146 at fold_idx 0 with RMSE: 0.6229152148725662
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.290727	valid_1's rmse: 0.580877
# Early stopping, best iteration is:
# [8]	training's rmse: 0.629762	valid_1's rmse: 0.462999
# Participant_146 at fold_idx 1 with RMSE: 0.462999235053309
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.278344	valid_1's rmse: 0.742275
# Early stopping, best iteration is:
# [10]	training's rmse: 0.569831	valid_1's rmse: 0.678995
# Participant_146 at fold_idx 2 with RMSE: 0.6789946071114207
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.288783	valid_1's rmse: 0.603236
# Early stopping, best iteration is:
# [51]	training's rmse: 0.370941	valid_1's rmse: 0.599297
# Participant_146 at fold_idx 3 with RMSE: 0.5992971847804915
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.276394	valid_1's rmse: 0.790991
# Early stopping, best iteration is:
# [61]	training's rmse: 0.336564	valid_1's rmse: 0.768599
# Participant_146 at fold_idx 4 with RMSE: 0.7685991214811728
#
# 5-Fold CV for participant: participant_158
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.215526	valid_1's rmse: 0.672663
# Early stopping, best iteration is:
# [28]	training's rmse: 0.386794	valid_1's rmse: 0.554886
# Participant_158 at fold_idx 0 with RMSE: 0.5548862072445409
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.233762	valid_1's rmse: 0.430139
# [202]	training's rmse: 0.171474	valid_1's rmse: 0.458688
# Early stopping, best iteration is:
# [94]	training's rmse: 0.240748	valid_1's rmse: 0.427221
# Participant_158 at fold_idx 1 with RMSE: 0.4272211053237523
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.216567	valid_1's rmse: 0.449282
# [202]	training's rmse: 0.160013	valid_1's rmse: 0.451393
# Early stopping, best iteration is:
# [119]	training's rmse: 0.203791	valid_1's rmse: 0.445724
# Participant_158 at fold_idx 2 with RMSE: 0.44572363627367767
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.19965	valid_1's rmse: 0.627888
# Early stopping, best iteration is:
# [25]	training's rmse: 0.42719	valid_1's rmse: 0.592432
# Participant_158 at fold_idx 3 with RMSE: 0.5924318482453551
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.223777	valid_1's rmse: 0.553934
# [202]	training's rmse: 0.166195	valid_1's rmse: 0.554391
# Early stopping, best iteration is:
# [79]	training's rmse: 0.247042	valid_1's rmse: 0.547325
# Participant_158 at fold_idx 4 with RMSE: 0.547325182560011
#
# 5-Fold CV for participant: participant_176
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.157805	valid_1's rmse: 0.567791
# Early stopping, best iteration is:
# [2]	training's rmse: 0.452498	valid_1's rmse: 0.459508
# Participant_176 at fold_idx 0 with RMSE: 0.45950825304277504
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.15898	valid_1's rmse: 0.705529
# Early stopping, best iteration is:
# [3]	training's rmse: 0.407955	valid_1's rmse: 0.610308
# Participant_176 at fold_idx 1 with RMSE: 0.6103076004423651
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.169455	valid_1's rmse: 0.381561
# Early stopping, best iteration is:
# [35]	training's rmse: 0.275825	valid_1's rmse: 0.364535
# Participant_176 at fold_idx 2 with RMSE: 0.3645349065750477
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.164282	valid_1's rmse: 0.385858
# [202]	training's rmse: 0.0990981	valid_1's rmse: 0.386363
# Early stopping, best iteration is:
# [78]	training's rmse: 0.188766	valid_1's rmse: 0.383086
# Participant_176 at fold_idx 3 with RMSE: 0.3830861194785424
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.170806	valid_1's rmse: 0.437635
# Early stopping, best iteration is:
# [36]	training's rmse: 0.271078	valid_1's rmse: 0.39742
# Participant_176 at fold_idx 4 with RMSE: 0.39742048959943843
#
# 5-Fold CV for participant: participant_21
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.127991	valid_1's rmse: 0.209972
# Early stopping, best iteration is:
# [23]	training's rmse: 0.266437	valid_1's rmse: 0.205006
# Participant_21 at fold_idx 0 with RMSE: 0.20500566527277642
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.110507	valid_1's rmse: 0.4843
# Early stopping, best iteration is:
# [20]	training's rmse: 0.234356	valid_1's rmse: 0.442348
# Participant_21 at fold_idx 1 with RMSE: 0.44234791324841916
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.135377	valid_1's rmse: 0.468883
# Early stopping, best iteration is:
# [1]	training's rmse: 0.359791	valid_1's rmse: 0.166421
# Participant_21 at fold_idx 2 with RMSE: 0.16642087372837025
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.12262	valid_1's rmse: 0.507348
# Early stopping, best iteration is:
# [25]	training's rmse: 0.20324	valid_1's rmse: 0.502484
# Participant_21 at fold_idx 3 with RMSE: 0.5024839259355051
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.139568	valid_1's rmse: 0.276494
# Early stopping, best iteration is:
# [7]	training's rmse: 0.315645	valid_1's rmse: 0.242064
# Participant_21 at fold_idx 4 with RMSE: 0.24206358026569916
#
# 5-Fold CV for participant: participant_60
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.167247	valid_1's rmse: 0.418077
# Early stopping, best iteration is:
# [1]	training's rmse: 0.341893	valid_1's rmse: 0.153126
# Participant_60 at fold_idx 0 with RMSE: 0.153125730912688
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.140184	valid_1's rmse: 0.507792
# [202]	training's rmse: 0.095791	valid_1's rmse: 0.501588
# [303]	training's rmse: 0.0756009	valid_1's rmse: 0.49765
# [404]	training's rmse: 0.0614742	valid_1's rmse: 0.496557
# [505]	training's rmse: 0.0514583	valid_1's rmse: 0.495607
# [606]	training's rmse: 0.0445091	valid_1's rmse: 0.493753
# [707]	training's rmse: 0.0391805	valid_1's rmse: 0.493095
# [808]	training's rmse: 0.0347626	valid_1's rmse: 0.49248
# [909]	training's rmse: 0.0310627	valid_1's rmse: 0.492099
# [1010]	training's rmse: 0.0278528	valid_1's rmse: 0.491921
# [1111]	training's rmse: 0.0250909	valid_1's rmse: 0.491596
# [1212]	training's rmse: 0.022575	valid_1's rmse: 0.491708
# Early stopping, best iteration is:
# [1107]	training's rmse: 0.0251674	valid_1's rmse: 0.491522
# Participant_60 at fold_idx 1 with RMSE: 0.491521746045731
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.162095	valid_1's rmse: 0.319348
# Early stopping, best iteration is:
# [48]	training's rmse: 0.21505	valid_1's rmse: 0.314529
# Participant_60 at fold_idx 2 with RMSE: 0.3145294181655453
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.150139	valid_1's rmse: 0.319422
# Early stopping, best iteration is:
# [1]	training's rmse: 0.334495	valid_1's rmse: 0.202798
# Participant_60 at fold_idx 3 with RMSE: 0.20279828538301695
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.143014	valid_1's rmse: 0.31393
# Early stopping, best iteration is:
# [1]	training's rmse: 0.318792	valid_1's rmse: 0.287902
# Participant_60 at fold_idx 4 with RMSE: 0.287902355099256
#
# 5-Fold CV for participant: participant_75
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.248618	valid_1's rmse: 0.769265
# Early stopping, best iteration is:
# [75]	training's rmse: 0.291986	valid_1's rmse: 0.753345
# Participant_75 at fold_idx 0 with RMSE: 0.7533449979657766
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.245217	valid_1's rmse: 0.736861
# Early stopping, best iteration is:
# [54]	training's rmse: 0.33738	valid_1's rmse: 0.721691
# Participant_75 at fold_idx 1 with RMSE: 0.7216906019585623
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.2481	valid_1's rmse: 0.674151
# [202]	training's rmse: 0.163434	valid_1's rmse: 0.689216
# Early stopping, best iteration is:
# [90]	training's rmse: 0.263926	valid_1's rmse: 0.671837
# Participant_75 at fold_idx 2 with RMSE: 0.6718371703859374
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.240036	valid_1's rmse: 0.666299
# Early stopping, best iteration is:
# [31]	training's rmse: 0.451947	valid_1's rmse: 0.630393
# Participant_75 at fold_idx 3 with RMSE: 0.6303928547168021
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.259216	valid_1's rmse: 0.575953
# Early stopping, best iteration is:
# [76]	training's rmse: 0.305859	valid_1's rmse: 0.571489
# Participant_75 at fold_idx 4 with RMSE: 0.5714891428948397
#
# 5-Fold CV for participant: participant_87
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.216963	valid_1's rmse: 0.846813
# [202]	training's rmse: 0.139864	valid_1's rmse: 0.873041
# Early stopping, best iteration is:
# [109]	training's rmse: 0.206843	valid_1's rmse: 0.845149
# Participant_87 at fold_idx 0 with RMSE: 0.8451487970896856
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.218158	valid_1's rmse: 0.497699
# [202]	training's rmse: 0.147744	valid_1's rmse: 0.525796
# Early stopping, best iteration is:
# [105]	training's rmse: 0.213577	valid_1's rmse: 0.496539
# Participant_87 at fold_idx 1 with RMSE: 0.4965385027199741
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.221861	valid_1's rmse: 0.720289
# [202]	training's rmse: 0.14219	valid_1's rmse: 0.73279
# Early stopping, best iteration is:
# [128]	training's rmse: 0.191611	valid_1's rmse: 0.710815
# Participant_87 at fold_idx 2 with RMSE: 0.7108150701366567
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.21046	valid_1's rmse: 0.711303
# [202]	training's rmse: 0.133044	valid_1's rmse: 0.689612
# [303]	training's rmse: 0.0946658	valid_1's rmse: 0.68301
# Early stopping, best iteration is:
# [278]	training's rmse: 0.102376	valid_1's rmse: 0.680878
# Participant_87 at fold_idx 3 with RMSE: 0.6808778355259071
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.154538	valid_1's rmse: 1.0795
# Early stopping, best iteration is:
# [31]	training's rmse: 0.628819	valid_1's rmse: 0.866699
# Participant_87 at fold_idx 4 with RMSE: 0.8666993275554002
#
# 5-Fold CV for participant: participant_89
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.259041	valid_1's rmse: 0.733955
# [202]	training's rmse: 0.172908	valid_1's rmse: 0.752251
# Early stopping, best iteration is:
# [90]	training's rmse: 0.273333	valid_1's rmse: 0.727884
# Participant_89 at fold_idx 0 with RMSE: 0.7278842958889413
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.229406	valid_1's rmse: 0.843098
# [202]	training's rmse: 0.158585	valid_1's rmse: 0.846121
# Early stopping, best iteration is:
# [89]	training's rmse: 0.243498	valid_1's rmse: 0.840963
# Participant_89 at fold_idx 1 with RMSE: 0.8409627980116421
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.262061	valid_1's rmse: 0.692072
# Early stopping, best iteration is:
# [70]	training's rmse: 0.313413	valid_1's rmse: 0.684451
# Participant_89 at fold_idx 2 with RMSE: 0.6844511130117406
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.294224	valid_1's rmse: 0.527675
# Early stopping, best iteration is:
# [37]	training's rmse: 0.462422	valid_1's rmse: 0.487096
# Participant_89 at fold_idx 3 with RMSE: 0.48709627943044687
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.314311	valid_1's rmse: 0.320309
# Early stopping, best iteration is:
# [70]	training's rmse: 0.36954	valid_1's rmse: 0.309083
# Participant_89 at fold_idx 4 with RMSE: 0.30908322702780117
#
# 5-Fold CV for participant: participant_96
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.354101	valid_1's rmse: 0.942291
# Early stopping, best iteration is:
# [23]	training's rmse: 0.743805	valid_1's rmse: 0.917187
# Participant_96 at fold_idx 0 with RMSE: 0.9154379379430589
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.436281	valid_1's rmse: 1.48345
# Early stopping, best iteration is:
# [76]	training's rmse: 0.48154	valid_1's rmse: 1.46611
# Participant_96 at fold_idx 1 with RMSE: 1.258928842033973
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.315722	valid_1's rmse: 1.54152
# [202]	training's rmse: 0.236217	valid_1's rmse: 1.56763
# Early stopping, best iteration is:
# [98]	training's rmse: 0.319562	valid_1's rmse: 1.5367
# Participant_96 at fold_idx 2 with RMSE: 1.603695597462559
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.353438	valid_1's rmse: 1.05911
# Early stopping, best iteration is:
# [41]	training's rmse: 0.531009	valid_1's rmse: 1.0179
# Participant_96 at fold_idx 3 with RMSE: 1.0149254183127474
#
# Training until validation scores don't improve for 125 rounds
# [101]	training's rmse: 0.37335	valid_1's rmse: 0.828142
# Early stopping, best iteration is:
# [39]	training's rmse: 0.573016	valid_1's rmse: 0.797333
# Participant_96 at fold_idx 4 with RMSE: 0.7904615594796335
#
# CV finished. Elapsed time: 0:01:14.727512

# %%
import json

global_rmse = 0
for participant, CV_info in best_CV_infos_LGBM.items():
    global_rmse += CV_info.score
    print(participant.capitalize(), 'scored {}, with params: {}\n'
                  .format(CV_info.score, json.dumps(CV_info.params, indent=2)))
    
print('Global RMSE: {:3f}'.format(global_rmse/len(best_CV_infos_LGBM.items())))
# Out:
# Participant_116 scored 0.572827925093408, with params: {
#   "objective": "regression",
#   "num_leaves": 35,
#   "learning_rate": 0.05,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.75,
#   "metric": "rmse"
# }
#
# Participant_120 scored 0.4195865788113713, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_146 scored 0.6271380505060996, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.1,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.75,
#   "metric": "rmse"
# }
#
# Participant_158 scored 0.5266296295398636, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_176 scored 0.451099228170429, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_21 scored 0.32213231987060825, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_60 scored 0.3078088890492373, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_75 scored 0.7020691573930705, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.3,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.87,
#   "metric": "rmse"
# }
#
# Participant_87 scored 0.7504267388854851, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.1,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.75,
#   "metric": "rmse"
# }
#
# Participant_89 scored 0.6244838645630377, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.1,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.75,
#   "metric": "rmse"
# }
#
# Participant_96 scored 1.1179106880387473, with params: {
#   "objective": "regression",
#   "num_leaves": 50,
#   "learning_rate": 0.1,
#   "bagging_fraction": 0.9,
#   "feature_fraction": 0.75,
#   "metric": "rmse"
# }
#
# Global RMSE: 0.583828

# %%
with open('best_CV_infos_LGBM.pickle', 'wb') as f:
    pickle.dump(best_CV_infos_LGBM, f)

# %% [markdown]
# ##### Testing IREN data

# %%
out_features=['date', 'participant']

num_folds = 5

test_Y_pred_LGBM = []

for participant in u_participants:
    print("Extracting {}'s data...".format(participant.capitalize()))

    # Separate current XY sets
    X_test_Participant = test_X_df.loc[test_X_df.participant
                                == participant].reset_index()
    
    # Collect dates in X
    X_test_Participant_date = X_test_Participant.date

    X_test_Participant.drop(columns=out_features, inplace=True)
    Y_pred_test_Participant = np.zeros(X_test_Participant.shape[0])
    
    test_single_Y_df = None
  
    for fold_idx in range(num_folds):
        model_LGBM = best_CV_infos_LGBM[participant].models[fold_idx]
        
        Y_pred_test_Participant += model_LGBM.predict(X_test_Participant,
                num_iteration=model_LGBM.best_iteration) / num_folds
                
        gc.collect()
        
    # Rounding since n_acc_offers are integers in N >= 0
    Y_pred_test_Participant = np.round(Y_pred_test_Participant).astype(int)
    Y_pred_test_Participant[Y_pred_test_Participant < 0] = 0
                      
    # Create the participant's DF entry
    test_single_Y_df = pd.DataFrame({'technology': enc_technologies.inverse_transform(
                                            X_test_Participant.technology),
                            'date': X_test_Participant_date, 'participant': participant,
                            'n_acc_offers': Y_pred_test_Participant})
    
    test_Y_pred_LGBM.append(test_single_Y_df)
    
    print("{} scoring is completed\n".format(participant.capitalize()))
    gc.collect()
        
test_Y_pred_LGBM_df = pd.concat(test_Y_pred_LGBM)

# Normalize the DF on the same multi-indexes I
# used to extract the target n_acc_offers from test_Y_df
test_Y_pred_target_LGBM = test_Y_pred_LGBM_df.pivot_table(index='date',
                                        columns=['participant', 'technology']) \
                                .swaplevel(axis=1).sort_index(1).to_numpy().ravel('K')
# Out:
# Extracting Participant_116's data...
# Participant_116 scoring is completed
#
# Extracting Participant_120's data...
# Participant_120 scoring is completed
#
# Extracting Participant_146's data...
# Participant_146 scoring is completed
#
# Extracting Participant_158's data...
# Participant_158 scoring is completed
#
# Extracting Participant_176's data...
# Participant_176 scoring is completed
#
# Extracting Participant_21's data...
# Participant_21 scoring is completed
#
# Extracting Participant_60's data...
# Participant_60 scoring is completed
#
# Extracting Participant_75's data...
# Participant_75 scoring is completed
#
# Extracting Participant_87's data...
# Participant_87 scoring is completed
#
# Extracting Participant_89's data...
# Participant_89 scoring is completed
#
# Extracting Participant_96's data...
# Participant_96 scoring is completed

# %% [markdown]
# ##### Performance and plots

# %%
print('Test RMSE error with LGBM: {}'.format(np.sqrt(calculate_MSE(
                test_Y_target_GBM, test_Y_pred_target_LGBM))))
# Out:
# Test RMSE error with LGBM: 0.6226998490772391

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams.update({'figure.max_open_warning': 50})

for i, pair in enumerate(unique_pairs):
    
    current_true_Y_df = test_Y_df.n_acc_offers[(test_Y_df['participant'] == pair[0]) \
                                & (test_Y_df['technology'] == pair[1])]
    current_pred_Y_df = test_Y_pred_LGBM_df.n_acc_offers[(test_Y_pred_LGBM_df['participant'] == pair[0]) \
                                & (test_Y_pred_LGBM_df['technology'] == pair[1])]
    
    true_Y = current_true_Y_df.to_numpy()
    pred_Y = current_pred_Y_df.to_numpy()
    
    current_MSE = np.sqrt(calculate_MSE(true_Y, pred_Y))
    
    print(pair[0].capitalize(), pair[1], current_MSE)
    
    plt.figure(i,figsize=(16,5))
    
    plt.title('{} {}: RMSE {:5f}'.format(pair[0].capitalize(), pair[1], current_MSE))
    
    plt.plot(current_true_Y_df.index, true_Y, label='True target', ls=':')
    plt.plot(current_true_Y_df.index, pred_Y, label='Prediction')
    
    plt.legend()
# Out:
# Participant_116 ccgt 1.0
# Participant_116 ccgt400 0.7559289460184544
# Participant_116 ccgt800 0.7559289460184544
# Participant_116 pump 0.0
# Participant_116 reservoir 0.6546536707079771
# Participant_120 ccgt800 0.0
# Participant_146 pump 0.6546536707079771
# Participant_146 reservoir 1.0
# Participant_158 ccgt400 0.0
# Participant_158 ccgt800 0.8451542547285166
# Participant_158 pump 0.8451542547285166
# Participant_158 reservoir 0.0
# Participant_176 ccgt800 0.3779644730092272
# Participant_21 reservoir 0.0
# Participant_60 ccgt400 0.0
# Participant_75 ccgt400 0.5345224838248488
# Participant_75 ccgt800 0.0
# Participant_87 ccgt 0.3779644730092272
# Participant_87 ccgt400 0.5345224838248488
# Participant_89 ccgt400 0.9258200997725514
# Participant_89 ccgt800 0.5345224838248488
# Participant_89 coal 0.0
# Participant_89 reservoir 0.0
# Participant_96 ccgt400 0.3779644730092272
# Participant_96 ccgt800 1.0
# Participant_96 coal 0.3779644730092272
# Participant_96 pump 1.3093073414159542
# Participant_96 reservoir 0.6546536707079771
